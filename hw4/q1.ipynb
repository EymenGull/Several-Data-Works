# %%
import json

import pandas as pd
import numpy as np
import networkx as nx

import matplotlib.pyplot as plt

from collections import Counter

# %%
def ingest_review_data(data):
    reviews = {}
    for line in data.split("\n"):
        if line.startswith("product/productId:"):
            product_id = line.split(": ")[1]
            reviews[product_id] = {}
        elif line.startswith("review/"):
            parts = line.split(": ")
            if len(parts) == 2:
                review_key, review_value = parts
                review_key = review_key.split("/")[1]
                reviews[product_id][review_key] = review_value
            else:
            #handle lines that do not contain a colon
                pass
    return reviews

# %%
with open("./Desktop/notebook/foods.txt", "r") as f:
    review_data = f.read()

reviews = ingest_review_data(review_data)

# %%
reviews
# Out:
# {'B001E4KFG0': {'userId': 'A3SGXH7AUHU8GW',
#   'profileName': 'delmartian',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1303862400',
#   'summary': 'Good Quality Dog Food',
#   'text': 'I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.'},
#  'B00813GRG4': {'userId': 'A1D87F6ZCVE5NK',
#   'profileName': 'dll pa',
#   'helpfulness': '0/0',
#   'score': '1.0',
#   'time': '1346976000',
#   'summary': 'Not as Advertised',
#   'text': 'Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".'},
#  'B000LQOCH0': {'userId': 'ABXLMWJIXXAIN',
#   'profileName': 'Natalia Corres "Natalia Corres"',
#   'helpfulness': '1/1',
#   'score': '4.0',
#   'time': '1219017600',
#   'summary': '"Delight" says it all',
#   'text': 'This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis\' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.'},
#  'B000UA0QIQ': {'userId': 'A395BORC6FGVXV',
#   'profileName': 'Karl',
#   'helpfulness': '3/3',
#   'score': '2.0',
#   'time': '1307923200',
#   'summary': 'Cough Medicine',
#   'text': 'If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.'},
#  'B006K2ZZ7K': {'userId': 'A3JRGQVEQN31IQ',
#   'profileName': 'Pamela G. Williams',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1336003200',
#   'summary': 'Wonderful, tasty taffy',
#   'text': 'This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!'},
#  'B000E7L2R4': {'userId': 'A1MZYO9TZK0BBI',
#   'profileName': 'R. James',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1322006400',
#   'summary': 'Yay Barley',
#   'text': "Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too"},
#  'B00171APVA': {'userId': 'A21BT40VZCCYT4',
#   'profileName': 'Carol A. Reed',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1351209600',
#   'summary': 'Healthy Dog Food',
#   'text': 'This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.'},
#  'B0001PB9FE': {'userId': 'A3HDKO7OW0QNK4',
#   'profileName': 'Canadian Fan',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1107820800',
#   'summary': 'The Best Hot Sauce in the World',
#   'text': "I don't know if it's the cactus or the tequila or just the unique combination of ingredients, but the flavour of this hot sauce makes it one of a kind!  We picked up a bottle once on a trip we were on and brought it back home with us and were totally blown away!  When we realized that we simply couldn't find it anywhere in our city we were bummed.<br /><br />Now, because of the magic of the internet, we have a case of the sauce and are ecstatic because of it.<br /><br />If you love hot sauce..I mean really love hot sauce, but don't want a sauce that tastelessly burns your throat, grab a bottle of Tequila Picante Gourmet de Inclan.  Just realize that once you taste it, you will never want to use any other sauce.<br /><br />Thank you for the personal, incredible service!"},
#  'B0009XLVG0': {'userId': 'A327PCT23YH90',
#   'profileName': 'LT',
#   'helpfulness': '1/1',
#   'score': '1.0',
#   'time': '1339545600',
#   'summary': 'My Cats Are Not Fans of the New Food',
#   'text': "My cats have been happily eating Felidae Platinum for more than two years. I just got a new bag and the shape of the food is different. They tried the new food when I first put it in their bowls and now the bowls sit full and the kitties will not touch the food. I've noticed similar reviews related to formula changes in the past. Unfortunately, I now need to find a new food that my cats will eat."},
#  'B001GVISJM': {'userId': 'AAAS38B98HMIK',
#   'profileName': 'Heather Dube',
#   'helpfulness': '0/1',
#   'score': '4.0',
#   'time': '1331856000',
#   'summary': 'Great Bargain for the Price',
#   'text': 'I was so glad Amazon carried these batteries.  I have a hard time finding them elsewhere because they are such a unique size.  I need them for my garage door opener.<br />Great deal for the price.'},
#  'B00144C10S': {'userId': 'A2F4LZVGFLD1OB',
#   'profileName': 'DaisyH',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1338854400',
#   'summary': 'YUMMY!',
#   'text': "I got this for my Mum who is not diabetic but needs to watch her sugar intake, and my father who simply chooses to limit unnecessary sugar intake - she's the one with the sweet tooth - they both LOVED these toffees, you would never guess that they're sugar-free and it's so great that you can eat them pretty much guilt free!  i was so impressed that i've ordered some for myself (w dark chocolate) to take to the office so i'll eat them instead of snacking on sugary sweets.<br />These are just EXCELLENT!"},
#  'B0001PB9FY': {'userId': 'A3HDKO7OW0QNK4',
#   'profileName': 'Canadian Fan',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1107820800',
#   'summary': 'The Best Hot Sauce in the World',
#   'text': "I don't know if it's the cactus or the tequila or just the unique combination of ingredients, but the flavour of this hot sauce makes it one of a kind!  We picked up a bottle once on a trip we were on and brought it back home with us and were totally blown away!  When we realized that we simply couldn't find it anywhere in our city we were bummed.<br /><br />Now, because of the magic of the internet, we have a case of the sauce and are ecstatic because of it.<br /><br />If you love hot sauce..I mean really love hot sauce, but don't want a sauce that tastelessly burns your throat, grab a bottle of Tequila Picante Gourmet de Inclan.  Just realize that once you taste it, you will never want to use any other sauce.<br /><br />Thank you for the personal, incredible service!"},
#  'B003F6UO7K': {'userId': 'A31OQO709M20Y7',
#   'profileName': 'Molly V. Smith "staral"',
#   'helpfulness': '0/1',
#   'score': '5.0',
#   'time': '1288310400',
#   'summary': 'THIS IS MY TASTE...',
#   'text': 'This offer is a great price and a great taste, thanks Amazon for selling this product.<br /><br />Staral'},
#  'B001EO5QW8': {'userId': 'A108P30XVUFKXY',
#   'profileName': 'Roberto A',
#   'helpfulness': '0/7',
#   'score': '1.0',
#   'time': '1203379200',
#   'summary': "Don't like it",
#   'text': "This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go."},
#  'B000G6RPMY': {'userId': 'AQ9DWWYP2KJCQ',
#   'profileName': 'Roel Trevino "protomex"',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1278028800',
#   'summary': 'not ass kickin',
#   'text': "we're used to spicy foods down here in south texas and these are not at all spicy.  doubt very much habanero is used at all.  could take it up a notch or two."},
#  'B002GWHC0G': {'userId': 'A2EFAW1P3DRXWO',
#   'profileName': 'TJ Fairfax',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1349395200',
#   'summary': 'Our guests love it!',
#   'text': "We roast these in a large cast iron pan on the grill (about 1/3 of the bag at a time).  The smell is wonderful and the roasted beans taste delicious too.  More importantly, the coffee is smooth; no bitter aftertaste.  On numerous occasions, we've had to send the roasted beans home with friends because they like it so much."},
#  'B004N5KULM': {'userId': 'A7ZK2A3VIW7X9',
#   'profileName': 'Peggy',
#   'helpfulness': '0/2',
#   'score': '5.0',
#   'time': '1319414400',
#   'summary': 'pretty expensive',
#   'text': 'This bag of candy online is pretty expensive, it should be cheaper in order to compete with grocery stores, other than that, its a good combination of my favorite candy'},
#  'B001EO5TPM': {'userId': 'A1E09XGZUR78C6',
#   'profileName': 'gary sturrock',
#   'helpfulness': '2/2',
#   'score': '1.0',
#   'time': '1215302400',
#   'summary': 'stale product.',
#   'text': 'Arrived in 6 days and were so stale i could not eat any of the 6 bags!!'},
#  'B005DUM9UQ': {'userId': 'A8OFFIAL6XTOH',
#   'profileName': 'Bill Shirer',
#   'helpfulness': '0/1',
#   'score': '2.0',
#   'time': '1338422400',
#   'summary': 'Taste is not so good.',
#   'text': "I purchased the Mango flavor, and to me it doesn't take like Mango at all.  There is no hint of sweetness, and unfortunately there is a hint or aftertaste almost like licorice.  I've been consuming various sports nutrition products for decades, so I'm familiar and have come to like the taste of the most of the products I've tried.  The mango flavor is one of the least appealing I've tasted.  It's not terrible, but it's bad enough that I notice the bad taste every sip I take."},
#  'B000E7VI7S': {'userId': 'AWCBF2ZWIN57F',
#   'profileName': 'C. Salcido',
#   'helpfulness': '0/2',
#   'score': '5.0',
#   'time': '1185753600',
#   'summary': 'pretzel haven!',
#   'text': 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'},
#  'B001GVISJC': {'userId': 'A3BDOAPSF96WGQ',
#   'profileName': '2tall',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1289260800',
#   'summary': 'Bigger then other brands'},
#  'B006SQBRMA': {'userId': 'ATYMT48R62ENE',
#   'profileName': 'Marie',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1327017600',
#   'summary': 'Best ever latice tart',
#   'text': "I ordered two of these and two of raspberry latice tarts directly from FantasiCakes website for a dinner party I was hosting. It arrived fresh and intact. Very good size. I froze half for later use. I am a pastry lover and these were the best I've ever tasted. The pastry was soft, the jam was really good and the taste was great. They were gone in no time. My guests were really impressed."},
#  'B0059WXJKM': {'userId': 'A25VFHVGI4CFTP',
#   'profileName': 'Diana Robinson',
#   'helpfulness': '0/1',
#   'score': '1.0',
#   'time': '1335744000',
#   'summary': 'Warning!  WARNING!  -ALCOHOL SUGARS!',
#   'text': 'Buyer Beware Please! This sweetener is not for everybody.  Maltitol is an alcohol sugar and can be undigestible in the body.  You will know a short time after consuming it if you are one of the unsuspecting many who cannot digest it by the extreme intestinal bloating and cramping and massive amounts of gas a person can experience. Nausea, diarrhea & headaches can also be experienced. I learned my lesson the hard way years ago when I fell in love with the sugar-free chocolates suzanne sommers used to sell.  I thought I\'d found sugar-free chocolate nirvana at first taste but the bliss was short lived when the terrible side effects of maltitol kicked in.  The discomfort was unlike anything I had ever felt before.  I blew up like a balloon and had very painful abdominal cramping.  As the symptoms passed, this too was very unpleasant.  Though hard for me to believe a low calorie sweetener could be the culprit, all symptoms were gone when I stopped eating the chocolate. My hunch it had something to do with the maltitol were unfortunately confirmed for me about a year later when I purchased some delicious sugar-free popcorn at my local market.  The taste was amazing and while I was looking at the label wondering what could possibly make this yummy, new sugarfree treat taste so good, my heart sank when I followed the little asterisk next to sugarfree sweetener* down to the very bottom of the label and read "maltitol" in tiny little letters! Thank goodness I\'d eaten only a little. I still ended up with all the same side-effects but for a much shorter duration. Some people can use maltitol to their heart\'s content but others, like me, can have a bad reaction to it. In case you\'re like me, ... it\'s not you ...it\'s the maltitol!'},
#  'B001EPPI84': {'userId': 'A27TZ4WBU7N0YF',
#   'profileName': 'I. So',
#   'helpfulness': '0/0',
#   'score': '1.0',
#   'time': '1275004800',
#   'summary': 'No Tea Flavor',
#   'text': 'No tea flavor at all. Just whole brunch of artifial flavors. It is not returnable. I wasted 20+ bucks.'},
#  'B004X2KR36': {'userId': 'A2AB7M9UCNBVN7',
#   'profileName': 'sharonh4',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1346976000',
#   'summary': 'Order only in cold weather',
#   'text': 'The taste was great, but the berries had melted.  May order again in winter. If you order in cold weather you should enjoy flavor.'},
#  'B005R8JE8O': {'userId': 'A3H1EQD2PBC085',
#   'profileName': 'jmc',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1344902400',
#   'summary': 'this is the best',
#   'text': 'i know i cannot make tea this good.  granted, i am not from the south but i know i have never enjoyed tea that was this sweet without being too sweet.  it tastes crisp.'},
#  'B0066DMI6Y': {'userId': 'AZLONLC8OZPEC',
#   'profileName': 'John W. Hollis',
#   'helpfulness': '1/1',
#   'score': '4.0',
#   'time': '1324598400',
#   'summary': 'Great',
#   'text': 'Great gift for all ages! I purchased these giant canes before and the recipients loved them so much, they kept them and would not eat them.'},
#  'B003ZFRKGO': {'userId': 'A2VOZX7YBT0D6D',
#   'profileName': 'Johnnycakes "Johnnycakes"',
#   'helpfulness': '15/15',
#   'score': '5.0',
#   'time': '1325635200',
#   'summary': 'Forget Molecular Gastronomy - this stuff rockes a coffee creamer!',
#   'text': 'I know the product title says Molecular Gastronomy, but don\'t let that scare you off.  I have been looking for this for a while now, not for food science, but for something more down to earth.  I use it to make my own coffee creamer.<br /><br />I have to have my coffee blonde and sweet - but the flavored creamers are full of the bad kinds of fat, and honestly, I hate to use manufactured "food" items.  I really don\'t think they are good for the body.  On the other hand, I hate using cold milk or cream, because I like HOT coffee.<br /><br />I stumbled across this on Amazon one day and got the idea of making my own creamer.  I also bought low-fat (non-instant) milk powder and regular milk powder. The non-instant lowfat milk is a little sweeter and tastes fresher than regular instant low-fat milk, but does not dissolve good in cold water - which is not a problem for hot coffee.  You will have to play with the ratios - I would not do just the heavy cream, it made the coffee too rich. Also, I think the powder is too expensive to just use on it\'s own. I like mixing 1/3 of each together.<br /><br />For flavoring, I bough cocoa bean powder, vanilla bean powder, and caster (superfine) sugar.  I mix up small batches along with spices like cinnamon and nutmeg to make my own flavored creamers.  If you wanted, you could use a fake sweetner powder instead.  I make up small amounts that I store in jelly canning jars. I also use my little food chopper/food processor to blend everything, so the sugar is not heavier and sinks to the bottom.  Let it settle for a bit before opening the top though.<br /><br />This stuff tastes WAY better than the storebought creamers and it is fun to experiment and come up with your own flavors.  I am going to try using some essential oils next and see if I can get a good chocolate/orange mix.<br /><br />All of the ingredients I mentioned are here online.  Take the time to experiment.  Maybe you don\'t use any low-fat milk. Or don\'t add any flavorings.  It is up to you.  Also, would make great housewarming/host(ess) gifts.<br /><br />I am sure other molecular people will be able to tell you more of what you can do with it, and I am sure I will experiment with it in cooking - but the main reason I bought it was to make my own creamer and it worked out great.'},
#  'B0019CW0HE': {'userId': 'A2P6ACFZ8FTNVV',
#   'profileName': 'Melissa Benjamin',
#   'helpfulness': '0/1',
#   'score': '1.0',
#   'time': '1331164800',
#   'summary': 'Bad',
#   'text': "I fed this to my Golden Retriever and he hated it.  He wouldn't eat it, and when he did, it gave him terrible diarrhea.  We will not be buying this again.  It's also super expensive."},
#  'B004K2IHUO': {'userId': 'A1ZKFQLHFZAEH9',
#   'profileName': 'S. J. Monson "world citizen"',
#   'helpfulness': '2/8',
#   'score': '3.0',
#   'time': '1236384000',
#   'summary': 'disappointing',
#   'text': "not what I was expecting in terms of the company's reputation for excellent home delivery products"},
#  'B001REEG6C': {'userId': 'AY12DBB0U420B',
#   'profileName': 'Gary Peterson',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1316390400',
#   'summary': 'My Idea of a Good Diet Food.',
#   'text': 'I\'m presently on a diet and I was at my Fresh and Easy Neighborhood Grocery looking over possible diet foods. I wanted things that were tasty, non-fat and low in calories. I came home with about a dozen items. That\'s how I discovered the Tillen Farms Pickled Crispy Asparagus. Well, I\'ve always liked asparagus anyway and I\'ve enjoyed several brands of pickled asparagus. This Tillen Farms brand is really, really good! It\'s the best I can recall. There\'s an excellent flavor and a big clove of garlic down in  the bottom of the jar which I\'m looking forward to eating. I can\'t believe how good this asparagus tastes and right on the front it says "only 60 calories per jar!" Now this is my idea of a good diet food!<br /><br />Gary Peterson'},
#  'B000J0HIT2': {'userId': 'A1VKJN5Y1C7S5Y',
#   'profileName': 'Wilhelmina Robinson "Wilhelmina Robinson &#34...',
#   'helpfulness': '2/2',
#   'score': '2.0',
#   'time': '1250812800',
#   'summary': 'Low Carb Angel Food Puffs',
#   'text': 'I was diappointed in the flavor and texture of this mix.  I usually like most of the Low Carb things I have tried, but was diappointed in this specific one.'},
#  'B0037LW78C': {'userId': 'A2IX1B76ONTXEL',
#   'profileName': 'Cinderella',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1326585600',
#   'summary': 'Wonderful Tea',
#   'text': 'I love this tea. It helps curb my eating during the day. My Mom and I have given it all friends to try.'},
#  'B0026Y3YBK': {'userId': 'A38BUM0OXH38VK',
#   'profileName': 'singlewinder',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1347667200',
#   'summary': 'Best everyday cookie!'},
#  'B003SE19UK': {'userId': 'A1LWFJRITZLYUG',
#   'profileName': 'PMG1',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1334188800',
#   'summary': 'Holistic select cat food',
#   'text': 'Our cats thrive extremely well on this dry cat food.  They definitely have much less hair ball throw ups and their fur is great.  They are fit and not over weight.  This vendor ships extremely fast.  Is one of the top Amazon suppliers in our book!'},
#  'B003OB0IB8': {'userId': 'A2BZNXMV0LC7OE',
#   'profileName': 'Alanna',
#   'helpfulness': '0/0',
#   'score': '4.0',
#   'time': '1333756800',
#   'summary': 'Tastes great, but is cheaper locally.',
#   'text': "I love this flavor of ramen! I don't eat other flavors anymore because they taste too bland by comparison. For the convenience of having it delivered to my home (I have prime, so I get it in two days and don't have to pay for the shipping), the price on amazon isn't bad at all, but it is still cheaper to run down and pick up a case of this at the grocery store."},
#  'B002SRYRE8': {'userId': 'A20PK3OCKRRSA5',
#   'profileName': 'Mrs. J. Todd',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1268265600',
#   'summary': 'Excellent Product/Life Saver',
#   'text': 'My son has had acid reflux since birth and has been on every medication available with no improvement, Until an older gentleman came into his work place and told him about this product and I automatically ordered it for him. I was really not expecting any better results than the 1000 other things we have tried. What a surprise! He has not had any heartburn or symptoms since day 2 of starting eating one piece of this Ginger each morning. He can now eat anything and actually enjoy it. This product was a God send for him. Thank you all for it!'},
#  'B001GVISJW': {'userId': 'A281387UUS2IN5',
#   'profileName': 'Beantown Jim',
#   'helpfulness': '0/1',
#   'score': '3.0',
#   'time': '1271548800',
#   'summary': 'Bite sized',
#   'text': 'I might be mistaken, but it appears that the pieces in this bag were reduced in size.  If they did do that, it was doubtlessly done to make it appear that the buyer got a better deal, having so many pieces after all.  The problem is that the pieces have to be a certain size in order to have enough flavor for your eating experience.  As it is, you have to use 2 or 3 pieces to match the old piece size;  it is not the same.'},
#  'B0017I8UME': {'userId': 'ATBE88PKKQTRA',
#   'profileName': 'Matthew R Lehmkuhler',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1344384000',
#   'summary': 'Love the salsa!!',
#   'text': 'This is one of the best salsas that I have found in a long time but stay away from the variety pack. The other two that come with it are not worth your money.'},
#  'B0064KU9HO': {'userId': 'AJFIH0DZYJF7T',
#   'profileName': 'Lisa Barton',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1350345600',
#   'summary': 'Ehhh...',
#   'text': "These remind me of dog treats I made once using pumpkin and cinnamon. They're kind of bland and not my favorite Back To Nature product. But my finace really loves them so that's where the three stars come from."},
#  'B0037ZFEW4': {'userId': 'ABTKZKAWOK4DC',
#   'profileName': 'huntersgun',
#   'helpfulness': '3/3',
#   'score': '5.0',
#   'time': '1326153600',
#   'summary': 'awesome cornmeal',
#   'text': 'This is the best cornmeal. I made regular cornbread and hot water cornbread with this meal and both were outstanding. Also fried some oysters with this meal, it gave them a great texture and flovor.'},
#  'B00374XSVY': {'userId': 'A2PW7DRW757OL0',
#   'profileName': 'Chris',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1335052800',
#   'summary': 'Awesome stuff',
#   'text': 'Works with chicken fish beef or pork. Fast easy and makes it taste excellent. Plus buying in bulk is more than 50% off from box stores'},
#  'B005P0HHGK': {'userId': 'AISCBGJRPPZ5G',
#   'profileName': 'KT "loves to read"',
#   'helpfulness': '0/0',
#   'score': '4.0',
#   'time': '1326585600',
#   'summary': 'tastes good',
#   'text': 'Got this for my brother who is on Jorge Cruise diet and decided to try one for myself.  It actually tastes pretty good.'},
#  'B002HQAXUW': {'userId': 'A17ESTP5T7T1PH',
#   'profileName': 'Bumbeda1',
#   'helpfulness': '1/1',
#   'score': '1.0',
#   'time': '1324944000',
#   'summary': 'Rip off Price',
#   'text': "These singles sell for $2.50 - $3.36 at the store for 1 box of 24 singles. I'm not sure why Amazon is selling it for $9.99 for a box of 24 singles.  Hazelnut coffee creamer is my favorite, but truly this is not a good buy."},
#  'B000SV90J8': {'userId': 'A3OO3TXDSIJDHY',
#   'profileName': 'pianolover',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1323648000',
#   'summary': 'Great flavor of Jell-o.',
#   'text': "I went to 4 grocery stores looking for this flavor of Jello for my green tomato jam recipe and finally found it here. This jello is wonderful! Evidently it's only carried in the stores during the summer but with harvest time in the Fall, I couldn't find it anywhere in town. This Jello tastes like watermelon and the jam recipe I made with it takes like watermelon jam! Great made as regular Jello too. Yummy!"},
#  'B0036VM05I': {'userId': 'A335SFRERY214N',
#   'profileName': 'D. Melo "Character Connoisseur"',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1349481600',
#   'summary': 'Great tasting sea salt WITH iodine',
#   'text': 'Perfect size sea salt for the table or the picnic basket.  We love it. Shakes well, no clumping and flows freely.'},
#  'B000ITVLE2': {'userId': 'ARTBQH9WOZTIV',
#   'profileName': 'Billy Wilson "amzrview"',
#   'helpfulness': '0/4',
#   'score': '1.0',
#   'time': '1269216000',
#   'summary': 'Tasteless but low calorie',
#   'text': 'Seriously this product was as tasteless as they come. There are much better tasting products out there but at 100 calories its better than a special k bar or cookie snack pack. You just have to season it or combine it with something else to share the flavor.'},
#  'B003TQQKFQ': {'userId': 'A2QHQM3HHFUSHG',
#   'profileName': 'Catherine Lea',
#   'helpfulness': '2/3',
#   'score': '5.0',
#   'time': '1334102400',
#   'summary': 'Best Stuff Ever',
#   'text': 'Used this in Moroccan recipes, as a syrup in a brilliant mixed beverage and as a swirled topping on sliced oranges soaked in orange water.  Wonderful, wonderful stuff!'},
#  'B007B9J6G2': {'userId': 'A34YK0ZTWOR858',
#   'profileName': 'NikkiBast',
#   'helpfulness': '1/1',
#   'score': '1.0',
#   'time': '1345420800',
#   'summary': 'Very Low quality',
#   'text': "I don't know how long these sat on the back of a shelf somewhere, but they were so old that they wouldn't cook.  I had to throw half of them out, because the skins were damaged, a clear sign of dried beans past their prime.  I can't even return these or ask for a refund, because food is not returnable.  Will find a different brand to use.  For now, I have about fifty servings of beans to throw away."},
#  'B0064KO0BU': {'userId': 'A104Y49ZQ4CYJ2',
#   'profileName': 'H. Adams "hollya"',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1344816000',
#   'summary': 'Worked great!',
#   'text': 'I purchased as a giveaway for a baby shower with Jungle theme! They worked out perfect for 25 small bags of candy. I purchased 5#. If you want more than 25 small bags, I would purchase a larger bag.'},
#  'B001IUKD76': {'userId': 'A2K8UBI64T0BM8',
#   'profileName': 'A. Carriglio',
#   'helpfulness': '3/3',
#   'score': '5.0',
#   'time': '1262131200',
#   'summary': 'Delicious!',
#   'text': 'I first had this drink when my mother brought it back with her from a visit to her home in Brittany France and thought it was delicious!  I wish it were a bit cheaper but other than that, I love this product!'},
#  'B0081XN2HQ': {'userId': 'A3HUV0ZQPXO3V7',
#   'profileName': 'Pink Dandy Chatter',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1344902400',
#   'summary': 'Fluffy, Soft, Delicious and Sugary Sweet',
#   'text': 'I couldn\'t wait to try the 8&#8243; Cinnamon Coffee Cake because it is made with fresh eggs, creamy sour cream, Madagascar Bourbon Vanilla and is topped and filled with cinnamon streusel. This 8&#8243; Cinnamon Coffee Cake is available online for only $18.95. Now, I have had my fair share of cinnamon coffee cakes, but, let me just tell you that the FantasiCakes Cinnamon Coffee Cake really "takes the cake" with size, price, quality and taste.<br />The cake arrived very fast and was carefully packaged so that it arrived in almost perfect condition. It also comes with a large tub of white icing that you can drizzle over the top, before serving. I couldn\'t believe how large the size was and it actually fed my family of 5 for us to enjoy during breakfast, for three days. The cake itself is thick and almost has a solid but sponge cake type consistency that is really moist and very filling. The flavors are to die for with the sticky cinnamon outside and sweet cinnamon and vanilla swirled throughout the inside of the cake. The icing really tops it off beautifully and gives it that moist and sticky sweet flavor. Pair the cake with your morning coffee and you\'ve got the perfect breakfast treat!'},
#  'B0025VRCJY': {'userId': 'A3L9ZT7SRJYLVH',
#   'profileName': 'JDTexan "JDTexan"',
#   'helpfulness': '0/2',
#   'score': '4.0',
#   'time': '1293926400',
#   'summary': 'ReaLemon Juice from Amazon.',
#   'text': 'This is not as good as the Frozen Lemon juice, but it is good. It has a slightly odd flavor, perhaps from a preservative. Sure wish I could order the frozen juice!'},
#  'B005CJVVJ8': {'userId': 'A1AL946PZ24084',
#   'profileName': 'Melinda K. Sanders',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1334707200',
#   'summary': 'Great product to help you sleep',
#   'text': 'WE have been looking for "natural" ways to help us sleep since we always seem to be overloaded with stress and a busy schedule. Yes, we\'d probably be better served taking a yoga class, but this is a good second choice. This helps you fall asleep and stay asleep. I drank half the first night and that was plenty for me. After about 30 minutes, I was ready for bed! I woke up refreshed and with no sleepy-drug hangover, so that is a huge bonus.<br /><br />I gave the product 3 stars (instead of the 5 it deserves) as their packing job was marginal at best. The product arrived with 2 broken bottles, which at this price is a $6 loss! The bottles are glass and all they did was wrap one layer of the small-bubbled bubble wrap around the case and placed it in a larger box with extra room to move around in that box. Big packing fail, but the product is awesome.'},
#  'B001KUUNP6': {'userId': 'A18VJ0WOQAIZYD',
#   'profileName': 'Ean Behr',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1337299200',
#   'summary': 'yum falafel',
#   'text': 'We had trouble finding this locally - delivery was fast, no more hunting up and down the flour aisle at our local grocery stores.'},
#  'B000NY8ODS': {'userId': 'A1IU7S4HCK1XK0',
#   'profileName': 'Joanna Daneman',
#   'helpfulness': '2/2',
#   'score': '5.0',
#   'time': '1333843200',
#   'summary': 'Make a fresh fruit tart, light and beautiful'},
#  'B00029XIZI': {'userId': 'A2S72TUJDQUBMH',
#   'profileName': 'Nadia',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1236124800',
#   'summary': 'Miracle',
#   'text': "My Scotties were full of hot spots and when I used this within a week all the hot spots were gone. The smell is kinda strong, but not bad. It's tolerablel."},
#  'B004V6AH34': {'userId': 'AJZ2A9UOJK0RB',
#   'profileName': 'LK',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1336089600',
#   'summary': 'Tastes Great. Arrived in 2 days!',
#   'text': 'Tastes great, and gives me energy without the jitters. Love this product.<br />However, I do wish it came in some sort of resealable jar or hard plastic container instead of a zip-lock pouch because the zip-lock ripped off and quit working after awhile. But the product is fantastic, just not crazy about the packaging.'},
#  'B0028C44Z0': {'userId': 'A3BJ9NS09YGQT5',
#   'profileName': 'Atl Chris "Atl Chris"',
#   'helpfulness': '0/3',
#   'score': '1.0',
#   'time': '1314489600',
#   'summary': "These just don't do it for me as breath mints",
#   'text': "To me, these are nothing like the regular Altoids and are not breath mints. They are pleasant-tasting little candies in a cute convenient tin, and that's as far as it goes. The mintiness is just not strong, and the wintergreens are definitely weaker than the peppermint minis. I'm not a dragon-breath person, but still, one of these mints is too small to have any effect on my breath. Four or five will freshen my breath for a short while - maybe 15 minutes. At this point, I think the Icebreakers Frost mints are the best as sugar free breath mints."},
#  'B0009XLVGA': {'userId': 'A1NHQNQ3TVXTZF',
#   'profileName': 'Desert Girl "chrissylovesherhusband"',
#   'helpfulness': '3/10',
#   'score': '1.0',
#   'time': '1220227200',
#   'summary': 'CHANGED FORMULA MAKES CATS SICK!!!!',
#   'text': 'As with canidae, Felidae has also changed their formula.  Cats do not like change when it comes to their food.  And they just had to change it without putting it on their label.  We noticed the color of the food had changed and so did the smell.  (As you will notice I have also reviewd the Canidae, and this all happened the same time the dogs were having issues.)<br /><br />Prior to the change in food we had almost lost two of our cats because we had moved to a new home.  If cats get "upset" because of a change in enviorment, or a loud noise they can stop eating.  It depends on the cat.  Two of them had stopped eating and had lost a lot of weight.  We took them to the vet and it took months to get them back to normal.  It has been a year since then and they are better.  Then the formula for this food changed.<br /><br />We started to noitce they were not eating as much and it started to bug us.  We asked the shop owner of the feed store and she had no knowledge of any change to the food.  It wasn\'t until the we were in there with other customers yelling about their dogs food making their dogs sick.  Right away we changed the cats food and they started chowing down and haven\'t suffered one bit like our dogs have.<br /><br />Cats are sensitve animals and changes to thier food could cause them to stop eating.  Anyone thinking of purchasing this food should not do it!  We have 5 rescued and fixed cats, none of which are picky eaters and the change in this formula could have been the death of them had we not found out about the change in their formula.<br /><br />I urge anyone that has had these problems to go to the consumer affairs website and also the FDA website and write a letter to them to let them know how this has affected your animal.  As with canidae they do not care how the change has affected my animals, and tell me not to buy it.  This is just horrible!'},
#  'B002TDK0VK': {'userId': 'A3GRP8QRFGDH8T',
#   'profileName': 'Technically Proficient',
#   'helpfulness': '1/4',
#   'score': '1.0',
#   'time': '1296086400',
#   'summary': 'Price cannot be correct',
#   'text': 'Hey, the description says 360 grams - that is roughly 13 ounces at under $4.00 per can. No way - that is the approximate price for a 100 gram can.'},
#  'B0040WAG7Q': {'userId': 'A19SDJ2TSSL8HI',
#   'profileName': 'K. McGee',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1347667200',
#   'summary': "More Hot/Spicy than McCormick's Brand",
#   'text': "My husband and I are both kind of wimpy when it comes to hot things and this seasoning is just a bit too spicy for us. It definitely makes you sweat a bit when you're eating it. It was still edible to us by adding a good sized dollop of sour cream but I don't think I would buy it again due to the heat. We prefer the milder McCormick's brand of Fajita mix. I've also had fajitas in a couple of different restaurants and it wasn't as spicy as this mix is.<br /><br />If you like super spicy then this is not burning hot so you might want to keep that in mind. To me it was more than medium hot but not by too much.<br /><br />I gave it three stars because it was pretty easy to make and it's versatile in that you could vary the veggies you put in it. You take a plastic bag, a couple of tbs of vegetable oil, 1/4 cup water and mix the seasoning, water and oil together then add the chicken strips to the bag and let it marinate for 5 minutes. In the meantime, it says to stir fry your veggies (peppers and onion) but I found it easier to just cook the chicken and veggies together and I don't think it affected quality or taste. I also used extra virgin olive oil rather than vegetable oil.<br /><br />I have one more package of this to use and next time I'm going to add more veggies and maybe some chopped tomato to cut the heat a bit more."},
#  'B001EO5ZMO': {'userId': 'A3A4GAPXRX5SHM',
#   'profileName': 'markiz',
#   'helpfulness': '1/3',
#   'score': '2.0',
#   'time': '1282435200',
#   'summary': 'Not a real tea',
#   'text': "Herbal additives in this blend destroy real tea taste. It is only for people who like herbal taste. I don't."},
#  'B001SATU8E': {'userId': 'A1CR1DS15Z7XO1',
#   'profileName': 'Tiff D',
#   'helpfulness': '0/0',
#   'score': '4.0',
#   'time': '1264377600',
#   'summary': 'DELICIOUS',
#   'text': 'Makes a tasty, super easy meal, fast. BUT high in calories.<br /><br />The instructions say to saute the veggies first but I recommend cooking the chicken first. The chicken takes longer to cook and the raw chicken ontop of veggies just makes a slimy mess. I made it with snow peas and carrots only. I dont like the little corn.  Added some red pepper flakes for heat and served ontop of rice.  It came out wonderful! Dinner on the table in less than 30mins.'},
#  'B007JFV6RK': {'userId': 'A2UC5JUVHIF80L',
#   'profileName': 'Abendago',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1334016000',
#   'summary': 'Mcclures bloody Mary mix',
#   'text': 'Took me one or two to get used to the pickle taste.  But now aim hooked and have to keep a bottle on hand'},
#  'B001L4ELRW': {'userId': 'A1AK335P17JXL0',
#   'profileName': 'Victoria Brown',
#   'helpfulness': '0/0',
#   'score': '1.0',
#   'time': '1345593600',
#   'summary': 'Not Good',
#   'text': "This candy is not as described. The middle is almost hard it is not a silky or smooth filling as described.<br />Looks and tastes like it's way past it's expiration date.<br />Would never reccommend this. Paid a good chunk of cash for nothing"},
#  'B003SO503C': {'userId': 'A3OXRFCJI67IMN',
#   'profileName': 'Bold Consumer',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1333843200',
#   'summary': 'Really Nice Taste!'},
#  'B003ZFXJDW': {'userId': 'AJ94Y22SUFCGU',
#   'profileName': 'Gwenhwyfar',
#   'helpfulness': '0/1',
#   'score': '5.0',
#   'time': '1303257600',
#   'summary': "Big tub o' salt",
#   'text': "These things are huge! I love the way the crystals crunch, and the flavor is not too overpowering or too subtle. This lemony flavor is my favorite--it's good on almost everything. You'll have plenty of flavored salt for a long time if you buy this."},
#  'B001HTL6CY': {'userId': 'A1KLA02LZXAT46',
#   'profileName': 'Dandelion',
#   'helpfulness': '0/0',
#   'score': '2.0',
#   'time': '1302307200',
#   'summary': 'Taste is neutral, quantity is DECEITFUL!',
#   'text': 'The taste of these white cheddar flat breads is like a regular cracker - which is not bad, except that I bought them because I wanted a cheese taste.<br /><br />What was a HUGE disappointment? How misleading the packaging of the box is. The photo on the box (I bought these in store) makes it look like it is full of long flatbreads (expanding the length and width of the box). Wrong! The plastic tray that holds the crackers is about 2" smaller all around - leaving you with about 15 or so small flatbreads.<br /><br />What is also bad about this is that the company states they use biodegradable and eco-friendly packaging. FAIL! They used a HUGE box for a ridiculously small amount of crackers. Not ecofriendly at all.<br /><br />Would I buy these again? No - I feel ripped off. The other crackers (like Sesame Tarragon) give you a little<br />more bang for your buck and have more flavor.'},
#  'B000WFRMRW': {'userId': 'A3Q7QBDSAZ670I',
#   'profileName': 'B. Barnett',
#   'helpfulness': '0/0',
#   'score': '4.0',
#   'time': '1331251200',
#   'summary': 'High Quality... But it gave my dog wicked gas..',
#   'text': "The recommendation when we bought our puppies (lhasa/bichon mix and lhasa/poodle mix) was that we continue them on the food that they have had since being weaned. This is a somewhat expensive food so I can't say that we were terribly pleased but we loaded up on the stuff and headed home.<br /><br />Let me just say this, I have had small dogs before. Never have I seen such gas issues. Both of them consistently had foul gas. Consistently. Usually when they're sitting on our laps but, you know. They're dogs.<br /><br />When we got through the first bag of this stuff, we purchased more on amazon. It was a great price for it since we got a 40 lb bag for the price of (I think) a 15 lb bag at Petco. But, they continued to have gas. I mean, they loved the food, don't get me wrong and they loved it more when we'd mix in some water and it would be like soft food. Somehow that made their gas worse but I think I'll have to give that responsible to the speed with which they chowed down- can't blame the food itself for gluttony.<br /><br />Eventually, we switched their food. No more farting. I think it was due to the high fat content which undoubtedly is necessary for very small puppies. They just need that in their diet. I think that we were advised to keep them on it for much longer than was useful (they said up until 1 year). Yeah right, you try dealing with gas for that long. Around 6 mos of age we switched to PuppyChow. Much better. Granted, they don't like it as much, but we humans like it a whole lot better."},
#  'B001EO5ZME': {'userId': 'AF72GTWZGAC61',
#   'profileName': 'Pinkhat',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1330387200',
#   'summary': 'Great tasting green tea and such a great deal.',
#   'text': 'A very delicate green tea with a smooth light taste and an subtle floral tones and no bitter aftertaste.<br /><br />In the 20+ years we have been drinking Ahmad teas not even once have we been disappointed. The superb quality of Ahmad teas has remained consistent throughout the years.<br /><br />I am so happy to find Ahmad teas available here (thanks Amazon!) because only a few stores carry it in my area and they are quite a few miles away. The current deal for the pack of 6 is superb (much cheaper than I can find locally).<br /><br />This is a great tasting tea, which I am happy to recommend.'},
#  'B0093NIWVO': {'userId': 'A1JT114SOITFFO',
#   'profileName': 'Dan & Eileen',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1350691200',
#   'summary': 'OMG best chocolate jelly belly',
#   'text': 'Fresh,a great way to get a little chocolate in my life without a million calories. They taste just like chocolate pudding.'},
#  'B001EO5ZMY': {'userId': 'A3E81HFGNME65J',
#   'profileName': 'suave',
#   'helpfulness': '1/9',
#   'score': '2.0',
#   'time': '1245456000',
#   'summary': 'Disappointed',
#   'text': "I've been drinking this tea for the past 8 or 10 years, usually buying a box or two when visiting large metropolitan areas, where many Middle-Eastern stores carry loose Ahmad teas, usually at $5-7 for a pound box.  I've always considered it an unremarkable but robust tea, with enough aroma and taste, and beautiful reddish color, perhaps not good enough a tea to drink on its own, but a decent base for mixes.<br />This tea, however, is nothing of the sort. Freshly opened package has almost no characteristic tea smell, and the brewed tea is weak, flat and tasteless.  Somehow it just does not seem to be the same product anymore. So, you get a lot of tea for the money, but the quality is such that you might as well drink Lipton bags, they are not that much worse."},
#  'B007TFONH0': {'userId': 'A3ICO2ROSXHIPM',
#   'profileName': 'tightwad',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1340755200',
#   'summary': 'delicious',
#   'text': 'good products and fast shipping equals a happy me. a little pricey but you can hand pick a few good flavors...a few i cant find anywhere else so def worth the price'},
#  'B000GGKQSO': {'userId': 'A1OE23J37ZPDXE',
#   'profileName': 'Donald Edward Liberman',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1270944000',
#   'summary': 'keeps you out of the dentest chair',
#   'text': 'If used on a daily basis you will keep your gums healty and between your teeth clean and free of plack.'},
#  'B007J32WX4': {'userId': 'A3957BBBNL1TLJ',
#   'profileName': 'Susan Hannon',
#   'helpfulness': '2/2',
#   'score': '5.0',
#   'time': '1334361600',
#   'summary': 'Super!  SuperFoods are Super easy!',
#   'text': "WOW!  This product is very impressive. I bought the 8oz blueberry and was pleased with packaging, price and shipping.  The powder dissolves instantly.  Even in water!  I've just been mixing a 1/4 tsp in a small glass of water for now and drinking it down and it tastes great!, but will add it to my smoothies and juiced fruit juices next. This product is so economical compared to purchasing fresh blueberries, especially because there is no waste due to mold or overripe berries thrown away.  I think you could add this to baked or unbaked foods as well.  I'm excited to add more of the SuperFoods to my diet in this fast and easy way. I definitely will being trying the other flavors soon."},
#  'B0017129DC': {'userId': 'A2EPNS38TTLZYN',
#   'profileName': 'tedebear',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1312675200',
#   'summary': 'Pok Chops',
#   'text': 'The pork chops from Omaha Steaks were very tasty but at the same time exceptionally dry. Pork is usually dry meat but these were to the extreme. Possibly shipping them frozen and keeping them frozen was partly the problem.'},
#  'B0002567IW': {'userId': 'A1SSKFPX72MSMR',
#   'profileName': 'Janna M. Sicard "missjanna"',
#   'helpfulness': '0/0',
#   'score': '1.0',
#   'time': '1344556800',
#   'summary': 'Sad outcome',
#   'text': 'Five minutes in, one tentacle was bitten off, ball inside cracked in half. Not durable enough to be a dog toy. Disappointed :(. So is the dog :(.'},
#  'B0048IC328': {'userId': 'A375ZA7IJH2ZGQ',
#   'profileName': 'Jihan S.',
#   'helpfulness': '3/7',
#   'score': '2.0',
#   'time': '1317772800',
#   'summary': "If you can't handle caffeine, this is not for you.",
#   'text': "Yes, it's probably healthier than 5-Hour Energy or Starbucks shots but if you're looking to avoid a caffeine overload, this is still not for you. Most energy drinks cannot be made w/ out a high dosage of caffeine. I believe the caffeine content of 1 Guayaki shot is 150 mL - probably lower than other un-healthy energy shot drinks but I believe most other people avoid the top brands b/c they contain too much caffeine and/or sugar. If you do not react well to caffeine, Guayaki is not a good buy either. I definitely feel an energy boost w/ 1 full Guayaki shot but not w/ out all the other caffeine side effects - irritability, nervousness, mood-swings. Caffeine overdose is why I stopped drinking coffee. But it looks even organic energy drinks are still not safe.<br /><br />Now you're NOT sensitive to caffeine, then it's a great buy. It's not loaded w/ sugar. The taste is easy and pleasant. It's not loaded w/ a bunch of chemicals like 5-Hour shots or Starbucks drinks. And the energy boost lasts for about 4 to 5 hours. Takes about 5 to 7 minutes to kick in but all this probably depends on your body/weight.<br /><br />Side note - if you want to feel energized during the day, have a protein drink first thing in the morning and stay away for heavy, fattening foods during the day that will make you feel sluggish and sleepy!"},
#  'B0025WIAN0': {'userId': 'A2WT4IIHNFJGYT',
#   'profileName': 'Diana KD',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1347321600',
#   'summary': 'Yum, Yummy, Yummier',
#   'text': "These Nature Valley Nut Lovers Variety Pack was perfect. Although I wasn't sure about the peanut butter bar, it was excellent. I loved the Roasted Almond, Roasted Pecan and the Peanut Butter.<br /><br />I will definately buy from this seller again. Quick shipping and very fresh."},
#  'B00821UN4M': {'userId': 'A3MQSTAAJSUGF9',
#   'profileName': 'mommy11',
#   'helpfulness': '1/1',
#   'score': '2.0',
#   'time': '1345161600',
#   'summary': 'Disappointed!',
#   'text': 'This product has a strong after-taste of Crayola crayons!<br /><br />I am in the process of trying different brands of coconut oils for cooking purposes.  Upon opening the plastic container, the aroma of crayons immediately fills the room, and this flavor permeates the food that is cooked in it.<br /><br />I suspect the source of the problem is the plastic used in the plastic container as I have not experienced this with any of the other brands purchased.<br /><br />To date, my favorite coconut oil is distributed by Barleans.  The flavor is fantastic.  However, they do not supply a gallon-sized tub,and Dr. Mercola has the best product in that size category.'},
#  'B00473RWXY': {'userId': 'AE508CW7ON3EP',
#   'profileName': 'armommi',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1348444800',
#   'summary': 'Great for Gluten-free lifestyle!!',
# ...
#  'B003BN7DLW': {'userId': 'AHYRTWABDAG1H',
#   'profileName': 'E. Thomsen "arvig"',
#   'helpfulness': '0/0',
#   'score': '4.0',
#   'time': '1309996800',
#   'summary': 'Very tasty product, but please note one odd issue',
#   'text': 'This is a very tasty product.  This is my first time trying this, and I am glad I ordered it to see how it tastes.  As a product I\'d order it again.<br /><br />One odd thing though that will cause me to lower this rating from 5 stars to 4 is that the listing here says a pound, but on the label 16 ounces is crossed out and 14 ounces is written next to it.  I didn\'t weigh the container to confirm this, but if it is 14 ounces, then then they need to update their listing to show such.<br /><br />Since I consider shipping to not be part of a product review I won\'t lower my star rating for this, and consider this to be just a mention of this then but the shipping was SLOW.  I ordered it on June 20th.  A USPS tracking/delivery confirmation number was generated on the 21st to be fair, but it took until July 5th for me to get this.  Even taking into account that there was a major holiday July 4th, that just seems too slow.  Everything was packaged well enough (although without anything like a "blue ice" pack to keep it cold for summer shipping...) but just took a long time to get here.  I do suspect the order wasn\'t truly shipped until the week before the July 4th weekend, despite a tracking number being generated on June 21st.'},
#  'B00579IZMY': {'userId': 'A3G330PGGGZK3W',
#   'profileName': 'Babysmama',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1350864000',
#   'summary': 'DELICIOUS',
#   'text': 'This was a gift from my Lil Sis.  Awesome.  Great flavor.  Can taste berries and rhubarb.  I love it.  Most likely will order more.'},
#  'B004553S6E': {'userId': 'AO4OIK8IVUXAP',
#   'profileName': 'Shauna',
#   'helpfulness': '0/0',
#   'score': '1.0',
#   'time': '1346976000',
#   'summary': 'Smelled horrible and gave the dogs the runs',
#   'text': 'If I could give this food a zero I would. I tried it out and the dogs loved it until they all had the runs for 2 days. It was horrible, smelled bad, and I would never get it again!'},
#  'B000JMBEAO': {'userId': 'A3HUPA4GDLGA3M',
#   'profileName': 'J. Devine "Tarnish29"',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1302825600',
#   'summary': 'Vimto',
#   'text': "Vimto, love it. Fekkin expensive here though!<br />That's the problem with no longer living back in Blighty, stuff like Vimto becomes much more difficult to get."},
#  'B0041HNGGS': {'userId': 'A3A1X149QRBTNT',
#   'profileName': 'So Cal Family',
#   'helpfulness': '14/28',
#   'score': '2.0',
#   'time': '1317168000',
#   'summary': 'As described but difficult to use',
#   'text': 'I bought the kit to dabble in spherification. The item is as-described and arrived on time. My complaint is that the instructions measure the required chemicals in fractions of grams. My kitchen scale measures as low as 1 gram but does not do fractions of grams. I cannot find a kitchen scale that measures fractions of grams. Therefore I find the kit difficult to use. I would not recommend the kit because it requires the purchase of specialized scale that can measure tenths of grams.'},
#  'B000634IIG': {'userId': 'A355DG9SA9AWQJ',
#   'profileName': 'D. Barba "Diane The Postal Worker"',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1217116800',
#   'summary': 'Healthy and Safe',
#   'text': "Soon after one dog was diagnosed with renal failure (Yes, she ate all the foods on that recall list), my Westie became ill and couldn't hold any food. The vet did all sorts of tests, but I had to find something gentle enough for him to keep down. That night I met a rep from Nutro at my local Petco. She told me all about Natural Choice, gave me literature and a website to learn more. I purchased this canned food along with a small bag of the dry food to mix with it. Turns out the dog had some sort of virus, but the food was the only food he could keep down to regain his strength. Due to skin allergies known to Westies, I have kept him on this food and find it's the best for him.<br /><br />I just don't understand, though, how this is sold so cheap on Amazon thru Petco. It's $16.99/case in the store and $15.99 on their website.  I think they should keep the price regulated throughout."},
#  'B001HBI29M': {'userId': 'AS0SPE5TEM74Z',
#   'profileName': 'Elizabeth Kingsley',
#   'helpfulness': '1/1',
#   'score': '3.0',
#   'time': '1286928000',
#   'summary': 'Needs more lemon flavor',
#   'text': "Not much of a lemon flavor for lemon cookies, more on the sweet side.  Coconut is listed in the ingredients, but you certainly won't taste it.  My son liked them, so they won't go to waste.  I would not buy them again."},
#  'B004NDFCSU': {'userId': 'A3IYSIAKYOMKTO',
#   'profileName': 'Renter',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1322956800',
#   'summary': 'Cat LOVES this stuff.',
#   'text': 'Now I know this formulation is not the most natural or high grade one on the market right now. Believe me, I have tried to get her interested in just about every brand with the word "natural" in the title, and she is not having it. She won\'t get the benefit of the food if she won\'t eat it. So when I noticed she was eating all of her food when I put this in front of her, I decided to stick with what is apparently working. This is still premium food, formulated for my twelve year-old\'s needs, and she really, really likes it. \'Nuff said.'},
#  'B002RJD2XY': {'userId': 'A1XQMQMF07QZQS',
#   'profileName': 'GalCalif "Visit my Amazon Profile page!"',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1304121600',
#   'summary': 'Cook up to be whole beans in a jiffy',
#   'text': "These are perfect if you want to add some beans to another soup, or just to have any size portion of black beans right away. As they are dried, they last forever, and you can have any portion size you want. With a little water and microwave, they perk up to give you really good quality black beans. I like these better than canned black beans, and I don't have any more at any time than I want. Adding them to soups which are too watery is a great way to thicken them up. You can't do that with canned beans which are mostly water in the first place. I haven't calculated the price out, but these are probably not any more expensive than canned beans because you aren't buying any water. Would be perfect for camping food as well."},
#  'B003JPHDIK': {'userId': 'A20ZFSDGEQ0X7J',
#   'profileName': 'trentonmike',
#   'helpfulness': '1/1',
#   'score': '5.0',
#   'time': '1319328000',
#   'summary': 'great new twist on old favorite',
#   'text': 'I was born and raised on the east coast  Trenton - New Jersey ). I have loved Tasty-Kakes my whole life , so its a great present to find some mew flavors or twists on old familiar receipes.'},
#  'B005GHVL1O': {'userId': 'A3ULSVWN3L23PW',
#   'profileName': 'Byrons3',
#   'helpfulness': '2/6',
#   'score': '3.0',
#   'time': '1334966400',
#   'summary': 'Not "Dublin" Dr Pepper',
#   'text': 'This is the new "Dublin" dr pepper now bottled in Temple Texas.  This is produced after Dr. Pepper force Dublin out of production.  It is not the same as Dublin Dr. Pepper, that is why it is so cheap.  If you want the real thing, you\'ll pay more for it.'},
#  'B004JQTDUO': {'userId': 'A3GKY9OEJQYKEE',
#   'profileName': 'william',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1328745600',
#   'summary': 'GREAT COFFEE',
#   'text': 'ESPECIALLY AS WE GET OLDER, THE LINING OF OUR STOMACH GETS MORE SENSITIVE TO HARSH CHEMICALS AND SUBSTANCES.  LOW ACID COFFEE IS A COMMON SENSE SUBSTITUTE THAT LOSES NO AROMA OR TASTE IN THE PROCESS.  HIGHLY RECOMMENDED.'},
#  'B000UOFW9K': {'userId': 'A1LARHHDXMS3CH',
#   'profileName': 'C. Meyer',
#   'helpfulness': '0/3',
#   'score': '1.0',
#   'time': '1269907200',
#   'summary': 'Hard as a rock with about as much flavor',
#   'text': "These things are like eating poker chips with seasoning salt.  They're remarkably high in calories, too!"},
#  'B002GWHCLK': {'userId': 'A33JGP7NR4BV8W',
#   'profileName': 'Tracie "tracieknits"',
#   'helpfulness': '1/4',
#   'score': '2.0',
#   'time': '1314144000',
#   'summary': 'very lightly roasted',
#   'text': "This is not a deeply roasted or rich tasting coffee at all.  It's very light, with unevenly sized beans -- clearly a blend.  Some beans are normal size and some are tiny.  The hazelnut aroma and flavor is good, but this coffee is not strong at all -- even using twice as many grounds, I could not get enough coffee flavor from these beans.<br /><br />People who like very weak coffee will probably love this.  People who like Starbucks will not like this one bit."},
#  'B0062I862I': {'userId': 'A10V0I4047U8FN',
#   'profileName': 'PERK K',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1345420800',
#   'summary': 'AWESOME!',
#   'text': 'I love this coffee. I tried it in Puerto Rico on our honeymoon and am hooked! I may even go back to Puerto Rico and get more!'},
#  'B0001WW41A': {'userId': 'A2R6NQS9YJZT1R',
#   'profileName': 'Donna',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1313971200',
#   'summary': 'heavy duty!',
#   'text': 'This is a hefty roll of mylar! The 50" width allows more coverage, obviously, but the 1 ml thickness is what\'s really nice.  It\'s not flimsy!'},
#  'B0025UA5I0': {'userId': 'A3Q4NNR7TYGRAV',
#   'profileName': 'ID politics poison',
#   'helpfulness': '0/0',
#   'score': '3.0',
#   'time': '1342396800',
#   'summary': 'Moist but bland',
#   'text': "This cake always turns out consistently sweet and moist, but bland.  Compared to the new deluxe Duncan Hines version of German Chocolate cake, this is not impressive.  It will do when you're craving something different from regular chocolate cake, though."},
#  'B000NY31I6': {'userId': 'A38D83HXZ207F2',
#   'profileName': 'twindg',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1345161600',
#   'summary': 'Excellent!',
#   'text': "This Creme Brulee is better than some of the better French restaurants I've been to. I just wish my local grocery stores would carry it!"},
#  'B004RDNGSY': {'userId': 'A3OCKYJNMQMKBL',
#   'profileName': 'V',
#   'helpfulness': '0/0',
#   'score': '1.0',
#   'time': '1344816000',
#   'summary': "This does not taste at all like Wild Bill's",
#   'text': "It tastes like Jack Links brand, not Wild Bill's.  Even the texture is totally different from Wild Bill's.  Not recommended!"},
#  'B001EO776Q': {'userId': 'A1UY7FXQ0G5BXC',
#   'profileName': 'Michae S. Sullivan "Docsullivan"',
#   'helpfulness': '0/0',
#   'score': '4.0',
#   'time': '1196035200',
#   'summary': 'Good stuff',
#   'text': 'Nice body and full roasted flavor at a reasonable price for a organic "fair trade".  I\'d buy the discounted pack again, but full price cost it too much to overcome my desire for an affordable coffee.'},
#  'B005OBHPUS': {'userId': 'ART1VF68PRI72',
#   'profileName': 'Rosemary K. Perkins "Roma Perkins"',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1349740800',
#   'summary': 'Brachs Manderin Orange Slices',
#   'text': 'I ordered this for my Mother-in-law who could not find this product anywhere near where she lives.  She is really enjoying this product.'},
#  'B0005Z6EUU': {'userId': 'A274MXTX3DYLUV',
#   'profileName': 'BB Indiana',
#   'helpfulness': '2/2',
#   'score': '5.0',
#   'time': '1284854400',
#   'summary': 'Very fresh and tasty',
#   'text': 'Very fresh and tasty SOFT buns that go well with my Omaha steak burger patties.<br />They store well.'},
#  'B0084B6CV8': {'userId': 'A14EEBPOJP2VPZ',
#   'profileName': 'Carol',
#   'helpfulness': '1/1',
#   'score': '3.0',
#   'time': '1341878400',
#   'summary': 'Eh.',
#   'text': "Chewy Lemonhead and Friends are my favorite candy. Period. I love them...so much.<br />...(cough)<br />So when I found these I was really excited and bought a pack hoping they'd have that same tartness that makes Lemonhead and Friends so good!<br />Nope. Tasted just like every other jelly-gummy type candy. I was very let down. It was okay for jelly/gummy, but don't expect much."},
#  'B001SAYI2W': {'userId': 'A3N7IG2EQPMLXL',
#   'profileName': 'Ali Jafar Al Moamen',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1345593600',
#   'summary': 'excelent preserve',
#   'text': 'very excelent quality preserve lingonberry,,i will order it again,,but the shipment pack should be covered better with strong materials,,thank u for the great felix lingonberry'},
#  'B000E1HVW0': {'userId': 'A2NAUQDLVN4CQM',
#   'profileName': 'Rj "Mad Mom"',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1298073600',
#   'summary': 'just like old times!',
#   'text': 'I remember the old days of having shake and bake BBQ ( I had a mother that was raising 5 girls alone). Chicken and the S & B were cheap to buy in these days and we ate it a lot.<br /><br />I never thought those memories could be recreated through smell and taste again, but oh My godness it was!!<br />It is just a delicious as I remember it being as a kid. I bought a case of 8 and have 6 more left. I don\'t know why the stores don\'t have this in stock...one clerk said its the msg in it. Well people should be able to make there choices of buying it or not buying it.<br />I am still amazed at the granular style it is and how it ends up this red sticky delicious old style bbq sauce that sticks to it like glue.<br />It is so gooood!! I highly recommend buying it and it would probably be good on ribs too!!<a href="http://www.amazon.com/gp/product/B000E1HVW0">Shake \'N Bake Seasoned Coating Mix, BBQ Glaze, 7-Ounce Boxes (Pack of 8)</a>'},
#  'B000E65OF6': {'userId': 'A1L52S6MPK3117',
#   'profileName': 'Kitty Yap',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1190678400',
#   'summary': "Wow, Im Addicted...But It's Great",
#   'text': "What a wonderful product!<br />I can drink it all times of the day, so obviously the original Sleepytime Tea causes no real drowsiness.<br /><br />I start my day with the tea and end it with the tea.<br />It makes me so relaxed and it's healthier then smoking..lol<br /><br />It's also made me a fan of sugarless tea.<br />Never again will I go back to sweet tea or terriable diet sodas!<br /><br />Try some Sleepytime Tea if you love tea! The flavor is amazing and very smooth as well as unique. It's great hot or cold!<br />You will not be dissappointed."},
#  'B000KOSDY6': {'userId': 'ARU0D5RK987RF',
#   'profileName': 'Rory C. Mccormack',
#   'helpfulness': '0/2',
#   'score': '2.0',
#   'time': '1287705600',
#   'summary': 'thought it would be better',
#   'text': 'so so.there was great reviews on product only made it once will try it again'},
#  'B000MIFPM8': {'userId': 'A2BE29LM6ZCQRI',
#   'profileName': 'John Smith',
#   'helpfulness': '0/1',
#   'score': '5.0',
#   'time': '1255737600',
#   'summary': 'Mmmmm...',
#   'text': 'Great for a snack (I eat a 2500 calorie/day diet)... I eat this between lunch and work and it hits the spot.  An entire bowl is 400 calories.  Arrived on time and its easier and cheaper than buying in bulk at ACME or other such (not costco but i dont have my own member card)'},
#  'B002ONWAWC': {'userId': 'A3GC7ZJB08KSI0',
#   'profileName': 'jmcdona3',
#   'helpfulness': '10/10',
#   'score': '1.0',
#   'time': '1299888000',
#   'summary': 'Unimpressed',
#   'text': "When the flowers showed up, they were in pretty bad shape.  I figured that water and the provided plant food would spruce them up within a few days.  Didn't happen.  They went from being dull and wilted to being dead within four days of arrival."},
#  'B0042GWL5A': {'userId': 'A2WX5JHGJFXK1O',
#   'profileName': 'LeeAnne DiLabio',
#   'helpfulness': '0/0',
#   'score': '5.0',
#   'time': '1325548800',
#   'summary': 'A wonderful gift!!',
#   'text': 'This 2 lb box of chocolates was a wonderful gift for my 20 year old niece!  The quality of the chocolates was amazing, but more importantly was the long lasting pleasure the young lady got.  A double gift!  Thanks Amazon!<a href="http://www.amazon.com/gp/product/B0042GWKWO">See\'s Candies 2 lb. Assorted Chocolates</a>'},
#  ...}

# %%
df = pd.DataFrame.from_dict(reviews, orient='index')

# %%
df = df.reset_index()
df = df.rename(columns={'index': 'product_id'})
df
# Out:
#        product_id          userId                      profileName  \
# 0      B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1      B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2      B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3      B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4      B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# ...           ...             ...                              ...
# 74253  B000H7K114  A2AGSSZR9V7XST                            Peter
# 74254  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 74255  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 74256  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 74257  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#       helpfulness score        time                             summary  \
# 0             1/1   5.0  1303862400               Good Quality Dog Food
# 1             0/0   1.0  1346976000                   Not as Advertised
# 2             1/1   4.0  1219017600               "Delight" says it all
# 3             3/3   2.0  1307923200                      Cough Medicine
# 4             0/0   5.0  1336003200              Wonderful, tasty taffy
# ...           ...   ...         ...                                 ...
# 74253         0/0   5.0  1281744000                       Excellent Tea
# 74254         0/0   5.0  1299628800                 Will not do without
# 74255         0/0   2.0  1331251200                        disappointed
# 74256         1/1   5.0  1331596800  Favorite Training and reward treat
# 74257         0/0   5.0  1338422400                         Great Honey
#
#                                                     text
# 0      I have bought several of the Vitality canned d...
# 1      Product arrived labeled as Jumbo Salted Peanut...
# 2      This is a confection that has been around a fe...
# 3      If you are looking for the secret ingredient i...
# 4      This taffy is so good.  It is very soft and ch...
# ...                                                  ...
# 74253  I love this tea.  I first discovered the pleas...
# 74254  Great for sesame chicken..this is a good if no...
# 74255  I'm disappointed with the flavor. The chocolat...
# 74256  These are the BEST treats for training and rew...
# 74257  I am very satisfied ,product is as advertised,...
#
# [74258 rows x 8 columns]

# %%
avg_scores = df.groupby('product_id')['score'].mean().reset_index()
avg_scores.columns = ['product_id', 'avg_score']
avg_scores
# Out:
#        product_id  avg_score
# 0      0006641040        4.0
# 1      141278509X        5.0
# 2      2734888454        5.0
# 3      2841233731        5.0
# 4      7310172001        5.0
# ...           ...        ...
# 74253  B009UOFTUI        1.0
# 74254  B009UOFU20        1.0
# 74255  B009UUS05I        5.0
# 74256  B009WSNWC4        5.0
# 74257  B009WVB40S        5.0
#
# [74258 rows x 2 columns]

# %%
review_counts = df.groupby('product_id')['score'].count().reset_index()

review_counts.columns = ['product_id', 'review_count']
filtered_products = review_counts[review_counts['review_count'] >= 100]
product_ids = filtered_products['product_id'].tolist()

print(f'Number of products with at least 100 reviews: {len(product_ids)}')
# Out:
# Number of products with at least 100 reviews: 0

# %%
product_ids
# Out:
# []

# %%
user_counts = df.groupby('userId')['score'].count().reset_index()

user_counts.columns = ['user_id', 'user_count']
filtered_users = user_counts[user_counts['user_count'] <= 50]
user_ids = filtered_users['user_id'].tolist()

print(f'Number of users with less than 50 reviews: {len(user_ids)}')
# Out:
# Number of users with less than 50 reviews: 55682

# %%
user_counts = df.groupby('userId')['score'].count().reset_index()

user_counts.columns = ['user_id', 'user_count']
filtered_users = user_counts[user_counts['user_count'] > 50]

user_ids = filtered_users['user_id'].tolist()

print(f'Number of users with less than 50 reviews: {len(user_ids)}')
# Out:
# Number of users with less than 50 reviews: 8

# %%
user_counts = df.groupby(['userId', 'product_id'])['score'].count().reset_index()

user_counts.columns = ['user_id', 'product_id', 'review_count']

filtered_users = user_counts[user_counts['review_count'] < 50]['user_id'].unique().tolist()

filtered_products = user_counts[user_counts['review_count'] < 100]['product_id'].unique().tolist()
filtered_products
# Out:
# ['B0026LJ3EA',
#  'B0026LIR60',
#  'B006Q820X0',
#  'B005DVVB9K',
#  'B008I1XPKA',
#  'B007OSBE1U',
#  'B007OSBEV0',
#  'B009PIAFTE',
#  'B009PIEW3O',
#  'B009PICJTS',
#  'B007Q3P1GC',
#  'B0024SGY8S',
#  'B003ZURMFS',
#  'B001RV8CGK',
#  'B001RVCAAE',
#  'B003F7YTK2',
#  'B001RPO15C',
#  'B005VUGT2W',
#  'B0077DF4Q8',
#  'B004ZBCJU4',
#  'B000NSFGVM',
#  'B001G6W0Y6',
#  'B0013T5YO4',
#  'B004CAOKSW',
#  'B002WDCIXK',
#  'B001CBHNPQ',
#  'B0002XAFTG',
#  'B000Q3AE2K',
#  'B0020LP6T2',
#  'B0078SITZK',
#  'B0027E4OH2',
#  'B00356BOKQ',
#  'B00356FRR2',
#  'B003YBJ9JA',
#  'B0028FKPUU',
#  'B00017L1UK',
#  'B001EQ4DG6',
#  'B005HY2BRO',
#  'B001AEFUIM',
#  'B004SKVWNW',
#  'B0001BVJB2',
#  'B000F3WSCU',
#  'B000V36U3M',
#  'B001IZHZYA',
#  'B000LKU7IE',
#  'B003OP8LMW',
#  'B003SNX4YA',
#  'B001GVIUKY',
#  'B0057FSWP8',
#  'B001PICXX8',
#  'B0002ML1EA',
#  'B006OP1Q8K',
#  'B002HQIPJ8',
#  'B0088A60PS',
#  'B0001M0YYO',
#  'B005EJJK6W',
#  'B0015MFQS8',
#  'B0014AUT60',
#  'B000UUS0KC',
#  'B0052Y15VW',
#  'B00012PPSY',
#  'B000ES1R1Y',
#  'B004Y4Z9CC',
#  'B003BI2HK4',
#  'B001IW08M4',
#  'B001GIE4YI',
#  'B0028SY210',
#  'B0050IM4MY',
#  'B002BKOM1K',
#  'B0014X3E3W',
#  'B0014X58EA',
#  'B0014X6H2M',
#  'B0015DXT4K',
#  'B000F7W1ZA',
#  'B001U7U6NS',
#  'B000RHUYF2',
#  'B004ZRGTO0',
#  'B0000D9MTL',
#  'B003H7MXQ2',
#  'B001H32G38',
#  'B0035IHTEE',
#  'B0035IRISG',
#  'B005Q8BS4S',
#  'B00332BXQ2',
#  'B000OQ2DJQ',
#  'B000OQ2DL4',
#  'B000WVY4PE',
#  'B000WVYB8Y',
#  'B00125ZCWI',
#  'B0019QT66I',
#  'B001E0TBA0',
#  'B001E18K8S',
#  'B002LN1ME2',
#  'B003SSWCJI',
#  'B00507SMSK',
#  'B001MOQI0Y',
#  'B007571ILQ',
#  'B001RCQZ1I',
#  'B0009F3PN0',
#  'B003MZBDZ6',
#  'B001189I3A',
#  'B002EDISKA',
#  'B003J9BCRO',
#  'B008JEHDY0',
#  'B0083KR8GS',
#  'B0064KO0BU',
#  'B0064KO16O',
#  'B0064KO222',
#  'B0002AQ1JW',
#  'B001M08XBU',
#  'B001EO5YU2',
#  'B000LKV3FU',
#  'B0015INICI',
#  'B0029TJTWA',
#  'B000FVVZ3U',
#  'B000KCYFFY',
#  'B0009XQWDW',
#  'B001SB2JPY',
#  'B000FVUIZQ',
#  'B0000KCKXK',
#  'B0000KCKXU',
#  'B000J3HWMC',
#  'B001CWCV1G',
#  'B001FQE2YI',
#  'B0019N37HK',
#  'B0083QJU0Y',
#  'B0039OINN0',
#  'B002U5A85U',
#  'B0002QEKPI',
#  'B001HTLCVO',
#  'B004FQO1Q4',
#  'B0051QSDMA',
#  'B003WEDT4A',
#  'B000LKZ3OM',
#  'B000MOQHCO',
#  'B000YDV444',
#  'B004JQTAKW',
#  'B001HTP2EC',
#  'B003E6GX8U',
#  'B0058RNX86',
#  'B000GUOA8W',
#  'B0064UD6K6',
#  'B004RZ0U36',
#  'B001M22LX4',
#  'B0077DRNYE',
#  'B004AXZEW2',
#  'B001BM6QHC',
#  'B000660LZM',
#  'B000096OIV',
#  'B0000GIOU2',
#  'B000FL3KDI',
#  'B000FL5482',
#  'B000I6MDO2',
#  'B000OIXE60',
#  'B000PNM0ZA',
#  'B000Y2G2W4',
#  'B00181UZFU',
#  'B001E5DXD6',
#  'B001E5DXDQ',
#  'B001E6J0BO',
#  'B001ELL4K4',
#  'B001ELL6IY',
#  'B001ELL706',
#  'B001EO65FU',
#  'B001EO7NOW',
#  'B001EPQ0EU',
#  'B001EPQCJ8',
#  'B001EPQXCE',
#  'B0029NTDEK',
#  'B002CZR8SI',
#  'B003E68MFM',
#  'B001AY9BQE',
#  'B003WEC2S4',
#  'B0001JXDO0',
#  'B000ZSWR76',
#  'B0048KK8JQ',
#  'B00014FT06',
#  'B000G7YRRO',
#  'B001EO5QW8',
#  'B004H4SHUA',
#  'B000LRIG1M',
#  'B001LQNX4M',
#  'B001FPT66S',
#  'B001FPV2RY',
#  'B001FQ0Z9Y',
#  'B0050DCOUQ',
#  'B0050DCP2I',
#  'B0000DZ0Q4',
#  'B0013AR19O',
#  'B0014EOU4S',
#  'B0014ET21Y',
#  'B004XXXK6Q',
#  'B001F1X2F8',
#  'B000R46M9M',
#  'B006TUSOV2',
#  'B004NSGK9K',
#  'B0018AFRGI',
#  'B0058DLSKK',
#  'B000PWTXE2',
#  'B0044W69PU',
#  'B0031MK6NK',
#  'B0015D22C0',
#  'B005P7YSG0',
#  'B002DHMUEW',
#  'B001IZLVE0',
#  'B004H4LM4I',
#  'B0029JES6W',
#  'B00012194I',
#  'B005GLKCQA',
#  'B005NDXHAY',
#  'B006683JYY',
#  'B002LUIMUC',
#  'B0001BGTVM',
#  'B0001BGU1G',
#  'B002RJGFTW',
#  'B000N42A0G',
#  'B001O8KR4Q',
#  'B000KKHRB0',
#  'B000SW4NNK',
#  'B001EQ5NHE',
#  'B005GIF5BK',
#  'B001M1FXYE',
#  'B001HTG4TO',
#  'B000J36SA4',
#  'B004MJDKZC',
#  'B000FZU08M',
#  'B002KA0V7A',
#  'B001DIQBNI',
#  'B000CONM8Q',
#  'B000CONMBS',
#  'B000FVWJAI',
#  'B000FDDESM',
#  'B00436SFOK',
#  'B008069XH2',
#  'B00061EUN6',
#  'B000G6MBUU',
#  'B003UI24QW',
#  'B001EO6802',
#  'B0085G4A7U',
#  'B000LKU0C2',
#  'B000E67210',
#  'B00286KM8E',
#  'B004CH6OFC',
#  'B002ZCZZ5G',
#  'B000F0DVZQ',
#  'B000LKU0NG',
#  'B000LKZLPS',
#  'B001EQ5HGG',
#  'B001EO5TNY',
#  'B0051NJBZ6',
#  'B004FYDF72',
#  'B001EO7FF4',
#  'B001EPQQX0',
#  'B005LB2D58',
#  'B002V02LOU',
#  'B006609HYI',
#  'B000RWBQ5O',
#  'B0006MWTTW',
#  'B000HQNH8E',
#  'B007B9GU9I',
#  'B000QY0CDK',
#  'B000WH2ZTA',
#  'B002TNJLVA',
#  'B00882BVGE',
#  'B00882BVRS',
#  'B005LDVJVK',
#  'B000PE84EK',
#  'B003KLQOO2',
#  'B0040YURMS',
#  'B0000D9N68',
#  'B002WF5JW0',
#  'B003LTPHV4',
#  'B001EHEEKK',
#  'B001NDZXV4',
#  'B0000UVRXY',
#  'B005QKH6P6',
#  'B007PA33MA',
#  'B000AXQI08',
#  'B001O3U7AK',
#  'B007R1PGVS',
#  'B006IMBO7C',
#  'B001QECTZ8',
#  'B003NCIDFG',
#  'B002VLR9YQ',
#  'B007TAP2AW',
#  'B007TKF59A',
#  'B000FDQV3C',
#  'B003YVMUFK',
#  'B004H1AIGY',
#  'B0044QC3L0',
#  'B0086UI36O',
#  'B000ZSX4D2',
#  'B001KVPC0G',
#  'B001KVPC8I',
#  'B004HOLDH4',
#  'B004HONIMC',
#  'B004HOQDK6',
#  'B001SAWQ8A',
#  'B003H1FUHM',
#  'B004XWRE78',
#  'B001EQ55T0',
#  'B001SAUJJS',
#  'B004R8L6NQ',
#  'B002ITCXHO',
#  'B003OP729U',
#  'B0000GJNYI',
#  'B001VIYAQA',
#  'B000162696',
#  'B001CCTZYM',
#  'B000XS90HS',
#  'B0032K3OI0',
#  'B007017SKW',
#  'B0018CDUNI',
#  'B003Y3D9R6',
#  'B004H9TR4K',
#  'B0078ERJFK',
#  'B001BKO3SS',
#  'B0002UKNZK',
#  'B001EQ54BE',
#  'B001UQAN5A',
#  'B00127FW80',
#  'B003WO3LAW',
#  'B008N04REE',
#  'B000Z0FUQE',
#  'B000Y02VZI',
#  'B000FPGYRI',
#  'B0079Y8KUC',
#  'B001E5DRWI',
#  'B000MXGMCK',
#  'B000MXGMFM',
#  'B000MXGMHA',
#  'B000MXHQS4',
#  'B000MXHQW0',
#  'B000MXJR5Y',
#  'B000MXJR72',
#  'B000MXJR7C',
#  'B003EMW6YE',
#  'B0002DIO2G',
#  'B000FOYMIC',
#  'B000FP0JY2',
#  'B000FED3QO',
#  'B0001H6D5S',
#  'B002UUOUD6',
#  'B001HNUBGW',
#  'B001SAU6FA',
#  'B001UDYIK4',
#  'B004XRJ8VS',
#  'B0000535LF',
#  'B001OXTTFO',
#  'B000LKVFJ4',
#  'B000H23ZF8',
#  'B001XQXZG6',
#  'B001E0FQG8',
#  'B004H6J1OO',
#  'B0005XNQTY',
#  'B0079OFZ32',
#  'B000I6PZM4',
#  'B0013T5A34',
#  'B0029T77HY',
#  'B000NY6QKG',
#  'B005MRUWLI',
#  'B00014ECZ4',
#  'B001JPGSM4',
#  'B002OK6E6I',
#  'B000WLEOR2',
#  'B001FB68XQ',
#  'B0025VPE9O',
#  'B004DCY4NA',
#  'B000OXCYKC',
#  'B003YJ14OU',
#  'B003YJ14QS',
#  'B00437AB1O',
#  'B001M2BM3O',
#  'B000WJ2WLO',
#  'B000ZE83FA',
#  'B0001M12PE',
#  'B000HJNAXI',
#  'B001EQ527U',
#  'B0026LIV8Y',
#  'B0045IK1CK',
#  'B000X5IPWM',
#  'B0000CAV3W',
#  'B004QY7JA0',
#  'B001EQ56XA',
#  'B0013C1CDS',
#  'B005YP9JJ4',
#  'B0007SNZES',
#  'B0039QXWZM',
#  'B001EPR15W',
#  'B0029JTZF6',
#  'B000LQJKWM',
#  'B003WO0740',
#  'B0000V82KY',
#  'B0035MTM3G',
#  'B0037N1ZEW',
#  'B000UI8K72',
#  'B0026LITWC',
#  'B00473QKGE',
#  'B004RHN3L0',
#  'B000BTIHAK',
#  'B0054FXRB0',
#  'B005469YQG',
#  'B004JLGCOE',
#  'B0001H22R6',
#  'B000GZW8F4',
#  'B00012OI1O',
#  'B004K8Z8X2',
#  'B000N9DIA2',
#  'B003DQ7YUW',
#  'B0045VZQOK',
#  'B0052OMSDG',
#  'B0056AWR8M',
#  'B0031DTZRW',
#  'B001J7MSS0',
#  'B000LR0LXI',
#  'B000LR2OTW',
#  'B000LR4F3U',
#  'B000LR4F4O',
#  'B000LR4F76',
#  'B000LR4F8K',
#  'B000LR4FA8',
#  'B000LR7QEK',
#  'B000LR7QIG',
#  'B0029JZGZE',
#  'B0001RVNLW',
#  'B0029NNCWE',
#  'B0029NR4LO',
#  'B003Y5OYZK',
#  'B003Y5P6CK',
#  'B003YU6A6Q',
#  'B000H28ADK',
#  'B0023USPGQ',
#  'B000NCXVJM',
#  'B00473QU96',
#  'B005EZ6KHI',
#  'B004N58QUE',
#  'B000O7JNXO',
#  'B000MXWWGU',
#  'B0018CJYTC',
#  'B007TDDOJU',
#  'B001F0R7IW',
#  'B001G3P1G8',
#  'B001OD1DZI',
#  'B002LTST10',
#  'B005GMFFPW',
#  'B00279NZGI',
#  'B004WF4HLM',
#  'B000FFLTD2',
#  'B002JP8R0Y',
#  'B001SB41O6',
#  'B004IN28IM',
#  'B0032K41JQ',
#  'B002PO5Y46',
#  'B002PO7ZZW',
#  'B003TVFBNS',
#  'B003N14DLU',
#  'B0010VUG0C',
#  'B003H7CSNU',
#  'B001E4Q5T6',
#  'B005GWLC54',
#  'B002HJ90JY',
#  'B000RHV0VO',
#  'B000F3PJIA',
#  'B0011DMUDK',
#  'B000F41ZFK',
#  'B004JQTBLU',
#  'B000ORXRKE',
#  'B001L54464',
#  'B006KD0TWK',
#  'B004CT9F9M',
#  'B005JXH2O0',
#  'B001EPQ4NM',
#  'B002TM53ZE',
#  'B003HGAX92',
#  'B000VTRCB0',
#  'B001UMKHV4',
#  'B002TSEWUK',
#  'B0007R4JUS',
#  'B004K6782I',
#  'B0034L4YOU',
#  'B004W1HDMQ',
#  'B0017WO2H2',
#  'B001EPQZWC',
#  'B006RW55DC',
#  'B001IZA22W',
#  'B001E5E1YG',
#  'B006ZDU2L8',
#  'B001A1PYHW',
#  'B0060KPGDK',
#  'B000QXAUNS',
#  'B00507QE94',
#  'B000WN5L5E',
#  'B005EX6M3C',
#  'B0028G9OD8',
#  'B0047243UA',
#  'B0000T15KU',
#  'B005FL8HVI',
#  'B000MN0NSE',
#  'B0062I862I',
#  'B001EO5NPI',
#  'B000084DYL',
#  'B00469M6VM',
#  'B004LS44IG',
#  'B0037AC7S8',
#  'B0018QYMMW',
#  'B003P6FR72',
#  'B003MUHD2S',
#  'B0005ZXPY8',
#  'B003YK5BQQ',
#  'B0029JVECI',
#  'B0019H32I0',
#  'B003747XQ0',
#  'B001ET63YI',
#  'B001SHURRK',
#  'B000RHSZBC',
#  'B00712NJ4E',
#  'B0029JFZZU',
#  'B0045SO9N2',
#  'B007A2LQRM',
#  'B004H0HL2Y',
#  'B000G1CPZQ',
#  'B0046LLEBS',
#  'B007CGL85Q',
#  'B004SI9EXO',
#  'B005MAIUS2',
#  'B0014WYXQK',
#  'B006VCXMRY',
#  'B0000GIVCI',
#  'B0005ZWBRK',
#  'B0029JRTVI',
#  'B002TXF6QY',
#  'B002U94ROE',
#  'B003Z5XW4I',
#  'B001CCJVJ6',
#  'B001D4F8HW',
#  'B001M0501Q',
#  'B001OBVZGM',
#  'B0007QRIGQ',
#  'B0019LFC2K',
#  'B0036QLHRK',
#  'B002QTWU4W',
#  'B007S871NQ',
#  'B0074UHTTO',
#  'B006ZAT8ZW',
#  'B0017T6S2M',
#  'B001NIV2EG',
#  'B000ZSZ5S4',
#  'B001EQ4P2I',
#  'B001EQ4QJK',
#  'B001EQ4RBM',
#  'B001KVPBS4',
#  'B001LNTY70',
#  'B004HOLD4W',
#  'B004HOLD60',
#  'B004HOLD92',
#  'B004HOOZEW',
#  'B004HOQE64',
#  'B004HOSGWE',
#  'B0018GDSH2',
#  'B00094YZH6',
#  'B001VJ3M0E',
#  'B0002QF27I',
#  'B000FPM5FS',
#  'B001BMSTX6',
#  'B003DGZPDU',
#  'B005CR441W',
#  'B00106VFXY',
#  'B0046YVVL8',
#  'B001EQ4IJS',
#  'B000NVCK68',
#  'B000NVDZ0I',
#  'B000NVFDT4',
#  'B005P0WL1G',
#  'B001M30NUG',
#  'B001NH5I4M',
#  'B0033CWBG8',
#  'B007RO7AVY',
#  'B007RO7BQ8',
#  'B007RO7CB2',
#  'B007ROG1L4',
#  'B007SG4MJ4',
#  'B005CN44XY',
#  'B000EEDJGO',
#  'B001EO5XDA',
#  'B001EQ5SN8',
#  'B000VZQTXG',
#  'B004VDGX1W',
#  'B0011MU2G8',
#  'B001202ETC',
#  'B0048Z8T9C',
#  'B004T38M6I',
#  'B001C5U8Z4',
#  'B002Z04S06',
#  'B001HTJF2W',
#  'B0007SNZHU',
#  'B00016XL40',
#  'B0067REUVK',
#  'B001EO67QC',
#  'B0004MVRII',
#  'B0019VROYO',
#  'B000GG0BM0',
#  'B00002N8SM',
#  'B000Z4JISQ',
#  'B0006GX1KO',
#  'B000BUPS56',
#  'B004T3BPVW',
#  'B006CGYPYS',
#  'B000NCN458',
#  'B000NCOLJ6',
#  'B002SZYPEM',
#  'B0080IP5RW',
#  'B000HIFAB4',
#  'B004SKKZGM',
#  'B00539MHP4',
#  'B000OV3WQE',
#  'B000NY31Y0',
#  'B001BWY67Y',
#  'B0057K1WSW',
#  'B0045TNRGQ',
#  'B0046GTKYG',
#  'B003H4YML4',
#  'B000Q9OV6E',
#  'B0026NLA8K',
#  'B004RVE0FE',
#  'B005ZKPA2S',
#  'B000UYIQ5M',
#  'B002AN6LL2',
#  'B001BLMKYQ',
#  'B001EQ52QQ',
#  'B0035YPGNO',
#  'B004TBD58K',
#  'B003FDGBU2',
#  'B000ILMQLM',
#  'B000DZSWT8',
#  'B004Q9QIPM',
#  'B000C0YYSM',
#  'B0017OGWLY',
#  'B004I19BA2',
#  'B004IN44U2',
#  'B000SBLNVG',
#  'B000SBPBA0',
#  'B0075YGV9I',
#  'B0000DG53S',
#  'B001VJ28Y0',
#  'B001VJ63LY',
#  'B001VJ9SMU',
#  'B0000TA36M',
#  'B000BXV6FY',
#  'B0012ORCZE',
#  'B0061S8PZW',
#  'B000OUY3IG',
#  'B0000DID76',
#  'B002TMV3E4',
#  'B002ER7SNE',
#  'B005XDUA9K',
#  'B0073XUMU0',
#  'B004W5M1K6',
#  'B00013VAXM',
#  'B004TPK2LE',
#  'B004S07G00',
#  'B004T72H88',
#  'B001EQ5G1C',
#  'B000HTLJW2',
#  'B001KUSLGY',
#  'B001EO7L12',
#  'B0088K7EZS',
#  'B000LKZAAY',
#  'B0055J86I4',
#  'B003VWMR0K',
#  'B0030MXL24',
#  'B000SQN3P0',
#  'B002RBTWHC',
#  'B007JTGOIW',
#  'B000NY8OLK',
#  'B000ES3LNG',
#  'B0078U6SS8',
#  'B002DGJ19K',
#  'B003O78GO8',
#  'B00028M6MA',
#  'B000HDMW6K',
#  'B008EE64AO',
#  'B008EE64FO',
#  'B006E0O6CS',
#  'B001SAYFSE',
#  'B0018MZ7Q6',
#  'B000W5U5H6',
#  'B00068PCTU',
#  'B000FVZGWG',
#  'B000KB910Y',
#  'B001M1V9OC',
#  'B000WG5AX4',
#  'B003M1KTUA',
#  'B000VQD4Z6',
#  'B0000TU7EK',
#  'B000FF5TDS',
#  'B000R9P996',
#  'B00122ECNQ',
#  'B001EO6BN6',
#  'B001EQ5F5Y',
#  'B0025UCDX0',
#  'B000J02OH8',
#  'B003E78B6Q',
#  'B007RY5RLY',
#  'B007ZXBSGU',
#  'B004HL1MDW',
#  'B0026002PU',
#  'B003G2LHUQ',
#  'B0082OCF8G',
#  'B003GB61SA',
#  'B000G1EO6E',
#  'B000BQVS0E',
#  'B00153WJ64',
#  'B000IJKSAK',
#  'B000F1WAMU',
#  'B001E530J8',
#  'B004NZAI8M',
#  'B000HP5FV2',
#  'B001EPPVHC',
#  'B0000E2T68',
#  'B000HE86QY',
#  'B0052AHU38',
#  'B004N5AVKC',
#  'B008LXKEWC',
#  'B001PMCDNY',
#  'B005NDXBA0',
#  'B005NDXBUK',
#  'B001EQ5KKO',
#  'B00355CNFW',
#  'B001P4F0H8',
#  'B000SOJWR0',
#  'B004E5BSTO',
#  'B0000DHZT8',
#  'B0012MWVT8',
#  'B003VXE3ME',
#  'B0002F7MX6',
#  'B007B1OTLM',
#  'B001HTBZ20',
#  'B006V2QK7S',
#  'B000OXL3TK',
#  'B000GC42TC',
#  'B00423CZ3G',
#  'B0055IWIPC',
#  'B002TM8AJU',
#  'B005G3OQ38',
#  'B001EO5YCK',
#  'B00063MSOM',
#  'B00063MSPG',
#  'B005258ALO',
#  'B004CH8342',
#  'B000UXA3GS',
#  'B001EQ5Q58',
#  'B003TRL83O',
#  'B004JR8F0M',
#  'B000FSPQTM',
#  'B000LKVJCC',
#  'B001BCVM7Q',
#  'B001EQ59EQ',
#  'B000LLHRKO',
#  'B003O78GFW',
#  'B002URN0DK',
#  'B0070HJYIU',
#  'B0009ET79C',
#  'B0064KODO4',
#  'B0064KOEJ8',
#  'B0064KOFAG',
#  'B0064KOG2S',
#  'B001KUUOH8',
#  'B0057P1MJQ',
#  'B001SB4DGC',
#  'B00032EGGO',
#  'B0048IC7CO',
#  'B00008DFB5',
#  'B0078U1G1M',
#  'B000BY9AJM',
#  'B004AAXMNI',
#  'B002NGHKW0',
#  'B001M08YZA',
#  'B004C8EXLS',
#  'B0026SHM96',
#  'B008H60B1M',
#  'B008PO7CWW',
#  'B000HDGD9M',
#  'B002MGCWBU',
#  'B004UJ6HDG',
#  'B000EHW0VQ',
#  'B004GKZN7A',
#  'B0002BGBLO',
#  'B000GF22LY',
#  'B000J2DQJQ',
#  'B000J2FSLU',
#  'B001E4Q54G',
#  'B001SAW31U',
#  'B006QQOWX8',
#  'B007DZYLCI',
#  'B001M0AM6E',
#  'B000GZY8XE',
#  'B000HDOOSE',
#  'B000P0VRW0',
#  'B001SAYDTK',
#  'B003VZM964',
#  'B002UR987M',
#  'B004Q3MB4U',
#  'B0000E6T2I',
#  'B0000E6T2K',
#  'B0000E6T2M',
#  'B0000E6T2N',
#  'B0012IVZXU',
#  'B001SB1F1I',
#  'B000KOUK6A',
#  'B000KOWLI0',
#  'B0030KNWPW',
#  'B0057XOCV8',
#  'B002HFWN5Q',
#  'B004ZY7D20',
#  'B00290RPPC',
#  'B001HNTZ0K',
#  'B0002IMRY2',
#  'B005OTXEVE',
#  'B0010V7BA0',
#  'B001VNGLA8',
#  'B004VLVRFQ',
#  'B001LO50SQ',
#  'B001B0SGTK',
#  'B003QNZ4KY',
#  'B003QNZ4TK',
#  'B000A0PNA2',
#  'B00474HAGW',
#  'B005OZZS7Q',
#  'B003QNJZWC',
#  'B00015MLVA',
#  'B001EQ564O',
#  'B004WP7JVM',
#  'B0056CFMQY',
#  'B005FC727M',
#  'B005GRBX7G',
#  'B005GTSOCQ',
#  'B005GTSP1Q',
#  'B005GTV75M',
#  'B005GWSSFQ',
#  'B005GWST5U',
#  'B005GWU822',
#  'B005GX55II',
#  'B005GX55XS',
#  'B005GXEULG',
#  'B005GXEVBA',
#  'B005GXGLFY',
#  'B005ZHOG5I',
#  'B0078DUNDG',
#  'B0081LDOJO',
#  'B00086IDXM',
#  'B0018CLW74',
#  'B004H882IS',
#  'B0061S323C',
#  'B003UK6WSQ',
#  'B001RPK5K2',
#  'B003XUL1V6',
#  'B000CQR6BS',
#  'B0032AM8HS',
#  'B004HOOZF6',
#  'B000LRIGE4',
#  'B000MQTHGK',
#  'B0029NTE2Q',
#  'B0049OX6IG',
#  'B000LRH640',
#  'B0000E5L18',
#  'B004EDHD1I',
#  'B007181742',
#  'B004Z9RL9U',
#  'B000KHU6AM',
#  'B000KHU6CA',
#  'B000I6RC8E',
#  'B0062QDZ0S',
#  'B0038EV0J0',
#  'B0029WXN2O',
#  'B002Z3M9WW',
#  'B000XSCKLG',
#  'B003CECKJA',
#  'B001HO21JG',
#  'B0012NLIIM',
#  'B006ODLCGI',
#  'B001HTIBZY',
#  'B00016ATJ0',
#  'B0041FPIWK',
#  'B003H3XLWG',
#  'B001DTIJUU',
#  'B004H6RM4A',
#  'B001XUIGG6',
#  'B002I06JVY',
#  'B001EN8PFO',
#  'B001VNGJ5K',
#  'B0009AFFLK',
#  'B0009AHL12',
#  'B0009AJQ06',
#  'B0009AJQ0G',
#  'B0009AJQ0Q',
#  'B0009ALUVE',
#  'B0000E5KZG',
#  'B0007WK1WI',
#  'B000CQOH24',
#  'B000HDKZKU',
#  'B002LGNT8Q',
#  'B0005ZIWV4',
#  'B000H23YZE',
#  'B003KLT0H0',
#  'B000SARHWG',
#  'B002F914G8',
#  'B0007NOWMM',
#  'B007JT7ARQ',
#  'B000QIHWKM',
#  'B0036IBTTE',
#  'B000F6UMH0',
#  'B0076R5D1Q',
#  'B0029NR3XS',
#  'B0029NUB3W',
#  'B0064O77LQ',
#  'B000NVXYV8',
#  'B0001WAMN2',
#  'B0044W2SG4',
#  'B001PUIN7Q',
#  'B002OHOC6A',
#  'B0001E3LCO',
#  'B0000DIPJA',
#  'B0001DMTQO',
#  'B000FVZW70',
#  'B001SB0R26',
#  'B000I346XQ',
#  'B001CLC87E',
#  'B000GZSI5I',
#  'B000PGQQFC',
#  'B003KSWCJ6',
#  'B004GL3TQ6',
#  'B004T6ZRD6',
#  'B004T6ZRFO',
#  'B0052HX7MO',
#  'B001EPQ1DA',
#  'B001LR3G4S',
#  'B001R7VT7S',
#  'B006MSEOJ2',
#  'B0009F3PIA',
#  'B007LRSK4S',
#  'B0020NJCR2',
#  'B007FMLMFS',
#  'B000IBRBFI',
#  'B000ES17HI',
#  'B000LJDQ06',
#  'B008FWOCZE',
#  'B000LKXRIQ',
#  'B001D20BHG',
#  'B00207XKBW',
#  'B0016D1C0W',
#  'B0000E6NMH',
#  'B0000DBN2G',
#  'B0000YUTUW',
#  'B000BH1NT4',
#  'B000BP5RZW',
#  'B004HZHHR8',
#  'B0052MFBD2',
#  'B0002CRZR2',
#  'B0000DJ6NI',
#  'B000CEZZ3G',
#  'B000GQ02Y2',
#  'B000NJEMFM',
#  'B000W283DC',
#  'B0012OPD9G',
#  'B0014EW5CC',
#  'B001ECQ4M6',
#  'B00021VGNC',
#  'B000CMJTJ4',
#  'B00019TVC8',
#  'B008C9QEVU',
#  'B001VJ3K56',
#  'B0047LTIJC',
#  'B001D0GV90',
#  'B000RNH2NI',
#  'B001EO5ZYW',
#  'B000HQOYJ0',
#  'B000084F44',
#  'B0002HBN0M',
#  'B000H7K0XI',
#  'B0060ZITWA',
#  'B008HRZ3GE',
#  'B00356UVYQ',
#  'B001PI4WQE',
#  'B0006GRC22',
#  'B006GZYY2I',
#  'B000IKCOW4',
#  'B004L609D2',
#  'B006WWN62Y',
#  'B007N3KG9C',
#  'B0093NII90',
#  'B0093NILCY',
#  'B00106TFSQ',
#  'B005U1ZB3U',
#  'B0010XEKEI',
#  'B001TANONA',
#  'B000WN13H4',
#  'B000LQNCEE',
#  'B0001G6V8I',
#  'B005IY3KTG',
#  'B00122E6UK',
#  ...]

# %%
filtered_users
# Out:
# ['#oc-R10LT57ZGIB140',
#  '#oc-R3GE8AOJOSUJVX',
#  '#oc-R3IX025L68IP59',
#  '#oc-R3LI5WJM4WD02C',
#  '#oc-R40PWE1BFHMT2',
#  '#oc-RNMDR27B0MP1I',
#  'A00489763J7YUCSN6CP7K',
#  'A0849196AFU725N8S7RS',
#  'A09229701Z8W88AD38877',
#  'A1000X0NY39BA1',
#  'A10012K7DF3SBQ',
#  'A10023OS6MZUC6',
#  'A1003YG3CPYQFS',
#  'A1005LM7YYY7VG',
#  'A1007OFJTJRYII',
#  'A100B9UOLABJS8',
#  'A100BT8Z05ASDC',
#  'A100DR1K6IUZUV',
#  'A100EBHBG1GF5',
#  'A100KABITNCJQZ',
#  'A100QR0G5OD7U5',
#  'A100TCEB7KB4B',
#  'A100WO06OQR8BQ',
#  'A10103MJIKKIFE',
#  'A1011I2PCI4K8B',
#  'A101C8YPYJ29CG',
#  'A101CCC619GN4S',
#  'A101CEZ1RKB1T7',
#  'A101F8M8DPFOM9',
#  'A101FZLX30BZ1T',
#  'A101K5ANDEC4N8',
#  'A101N9IT72VFSU',
#  'A101P5UBAWDB62',
#  'A101QLG5FZ2BKS',
#  'A101QYDENLLF4M',
#  'A101XJR335QHU7',
#  'A10216VMEXTY19',
#  'A102714YQ4VYZP',
#  'A1029CAC8JRPJX',
#  'A102ALA6MI312B',
#  'A102FG70Q4TGRT',
#  'A102GP5X0OU8GM',
#  'A102NBEATBBBO4',
#  'A102NQYJ3LLR7V',
#  'A102NX3G2DMOHH',
#  'A102OYXZJJEAYM',
#  'A102PC4WQJVR96',
#  'A102PUUO2U0YBK',
#  'A102R0714VSMB',
#  'A102SH9AIMFJSS',
#  'A102SLZLSMAXRE',
#  'A102T4DKZN8UFC',
#  'A102XKYZE9Q9L4',
#  'A102YXF8ENHFRL',
#  'A102Z9CFJOOZAY',
#  'A1031HORQ1693I',
#  'A1035WL2NYDXPI',
#  'A10389W8OI4Q6N',
#  'A103EZCS9H8WW1',
#  'A103FPM7ABVMAW',
#  'A103I0ZZLLNUJI',
#  'A103IV57K7GJUU',
#  'A103OBWVC0K1BZ',
#  'A103OW9PCYAXXH',
#  'A103QPEV0VWKLW',
#  'A103V3XNIYXVMS',
#  'A10413KVLWSR0B',
#  'A1043TKRFO4396',
#  'A10443LYX7DN89',
#  'A1044ECGVEMJ4J',
#  'A1046ICIMHENBN',
#  'A1047EDJ84IMAS',
#  'A104BMR0QRIDSZ',
#  'A104EM44JSX3HL',
#  'A104FF3C0UPVA5',
#  'A104FPCARJYVPP',
#  'A104MR5WHC3OAN',
#  'A104S66OE9H2T1',
#  'A104VOBVP67W5F',
#  'A104Y49ZQ4CYJ2',
#  'A105665OLFUKGD',
#  'A105B00OFXHAVE',
#  'A105CX9ZOHSR50',
#  'A105FFKEIEQJS9',
#  'A105G0U2S73Z3E',
#  'A105MTA2X8Q9OT',
#  'A105WK4IF15MXJ',
#  'A105Y1IU5YRF9B',
#  'A10618V3R162HC',
#  'A10645R22JIJ85',
#  'A106DQ6FX069TX',
#  'A106DRULDOULK8',
#  'A106G97JH0OTU9',
#  'A106L5R49CD8T3',
#  'A106MB2IVYFRWR',
#  'A106MNO7PYG1WL',
#  'A106R34K3VRITJ',
#  'A106R36BNKKMCO',
#  'A106X6HMD3NE76',
#  'A106X7HZI0GHU',
#  'A106XQ9D5VH48E',
#  'A106Y4RAMH4LRD',
#  'A106YK8JBW1JBP',
#  'A106ZCP7RSXMRU',
#  'A1072LLI2DPQL6',
#  'A1074ZS6AOHJCU',
#  'A1076JVUB6J67M',
#  'A1076UA29SK59D',
#  'A1078U03WV2Y70',
#  'A107C8TP3SW0ZA',
#  'A107JX0JQRQUUP',
#  'A107OP0RAXV1WT',
#  'A107PERM0JTLQB',
#  'A107TOIRSQ1JWX',
#  'A107VKWCI8SN8G',
#  'A107W3PSC48JB',
#  'A107ZAYC4MMN0C',
#  'A1080SE9X3ECK0',
#  'A1080VOU32OCLY',
#  'A1083JVJORII1Z',
#  'A1085AC8NOIOQK',
#  'A108AL4ECMBV9X',
#  'A108GOZ37A7B75',
#  'A108KZJAD7SME',
#  'A108P30XVUFKXY',
#  'A108Q6IELVGA47',
#  'A108RE198BZZ7P',
#  'A108RP07Y6GDO0',
#  'A108RRSQW5NTGU',
#  'A1091FSPSDID5V',
#  'A1097WLPUXJYXK',
#  'A10993ETJGGYCS',
#  'A1099W99IQ2XJW',
#  'A109E11621FM28',
#  'A109MFDOUXIKCP',
#  'A109R1CT8DF49E',
#  'A109UDZB70HFRF',
#  'A109VBXN1OUQF3',
#  'A109VTGM6ALZZ7',
#  'A109W8CR31K3ED',
#  'A109Y97NHQS4D6',
#  'A10A48FIL3OEJ2',
#  'A10ACPC0I87JZQ',
#  'A10AFMY8FACLEQ',
#  'A10AFVU66A79Y1',
#  'A10AR8K0M3P3RS',
#  'A10ARFGFWMVO9G',
#  'A10AVFDDU87KJ4',
#  'A10AZVYK32ZJSE',
#  'A10B25RO92V1X',
#  'A10B2TE7OUI2BI',
#  'A10B7AEATKKIU',
#  'A10B8KQ8LR4V89',
#  'A10BGWXSYYBHI2',
#  'A10BHLUILIS817',
#  'A10BK26EN1YSZT',
#  'A10BK2PYM9XMNS',
#  'A10BKAITA9Y64O',
#  'A10BV1TS2NCVSK',
#  'A10BXT30EK7U5C',
#  'A10CE51HOOMFA9',
#  'A10CII4A4R8RW3',
#  'A10CKKVSDK56RN',
#  'A10CMD69FMCFR8',
#  'A10CMEPEV19WAB',
#  'A10CMFLN1PVPE5',
#  'A10CQ4RIE8UEDP',
#  'A10CX62O7R3JFS',
#  'A10D02RQH2SRC6',
#  'A10D3AOK6XRGO6',
#  'A10D847GNWSZP8',
#  'A10D8CFB8WTF6L',
#  'A10D8ZLETMXNYR',
#  'A10DCJZGNVJVCX',
#  'A10DDNX5565YDX',
#  'A10DET5CP2SBMB',
#  'A10DI5LKUMPEBU',
#  'A10DNB08BPIJ2C',
#  'A10DRHWKS6NQUX',
#  'A10DS8DRAPSRIT',
#  'A10DY3JVAE3U3Q',
#  'A10E39L37HPMJV',
#  'A10E4NI80PAZF0',
#  'A10E54F03PGSQI',
#  'A10E8LEIEZV79L',
#  'A10E9GPB8UHE2Q',
#  'A10E9L65009UGU',
#  'A10EC3JV6482PZ',
#  'A10EEPCU4SZO06',
#  'A10EH2M5KLJQJ3',
#  'A10EHON996U8I1',
#  'A10EHUTGNC4BGP',
#  'A10EPXK6UFLZG6',
#  'A10EQDBQPTO7LE',
#  'A10ETISEXZPFLN',
#  'A10EY5DXDP56DW',
#  'A10EZ3EJY8G7G5',
#  'A10F0D8JQU9WBB',
#  'A10FHO7MT2A9BR',
#  'A10FJGRMOTJ35Y',
#  'A10FL3TBQ7TI48',
#  'A10FOB6FBXPJY5',
#  'A10FW0SRWO1Z4W',
#  'A10G6TFYLJ6BBI',
#  'A10G97HK0DYBR0',
#  'A10G9DLVFOA5JC',
#  'A10GAFWUEVGIG2',
#  'A10GBEDF4RCOVI',
#  'A10GHGVC5WBJ6E',
#  'A10GIZNRVH709L',
#  'A10GJC9YYBMTSR',
#  'A10GKM76NOQLGE',
#  'A10GNQRCQFJC36',
#  'A10GPKS1JPUZL6',
#  'A10GTLAY7TZDQ6',
#  'A10GVY892KV8P8',
#  'A10GYGJEMQ6VTI',
#  'A10H08THD3BTWI',
#  'A10H202J3QJX4R',
#  'A10H47FMW8NHII',
#  'A10H4KA3FDZAZA',
#  'A10H6731Y1BXRM',
#  'A10HAK3VK21HAO',
#  'A10HJS3SZ7QC3',
#  'A10HKIV590YPGF',
#  'A10HKY36OJHHS7',
#  'A10HM0S2J1P013',
#  'A10HN7T837W2B4',
#  'A10HQIH42AZKGP',
#  'A10HYE9LMUG4HW',
#  'A10I3E97UJUMG',
#  'A10I3GPBSB5MEE',
#  'A10IG68EQLTD7G',
#  'A10IHLC6D5IZK',
#  'A10IJEOBOPIDR9',
#  'A10IKJ2HKICWEN',
#  'A10IQ4MVRO05LM',
#  'A10ISIHD7YXJUM',
#  'A10IT7BG5QNSL5',
#  'A10IUTMPZ5B95S',
#  'A10IYKZYXZ97Q1',
#  'A10J0VP1DZ94RY',
#  'A10JA1HQCBNDVF',
#  'A10JDFMH3PQ28U',
#  'A10JNC7TDWUZK3',
#  'A10JNPPBHIKP34',
#  'A10JPCS67D74F7',
#  'A10JPLCSKEB436',
#  'A10JQDIYS3PARZ',
#  'A10JTOV6RNNTCF',
#  'A10JWNN14O49CF',
#  'A10JXTD58PH332',
#  'A10K41QA6YVOXR',
#  'A10K7E9F0THV3',
#  'A10KDCHTN93YML',
#  'A10KG51KKFCDUX',
#  'A10KLMD5SHX22O',
#  'A10KOPU41H0WLF',
#  'A10KY1E16FXEGB',
#  'A10L132FI5QHV6',
#  'A10LIGIT9EGCM9',
#  'A10LM0GAKTZTC3',
#  'A10LMJ2H7TU17N',
#  'A10LO4GLFBUFEX',
#  'A10LWFKVC21F82',
#  'A10LZHOJ0910QE',
#  'A10M36I150QVPH',
#  'A10M535MSKO6YJ',
#  'A10M6EMAXEANY2',
#  'A10MB3X3QKRDI0',
#  'A10MBPTTQA249A',
#  'A10MBQRNFXYI38',
#  'A10MHU9NOR190B',
#  'A10MPM6ZA9LNK3',
#  'A10MR5DG3TVWT4',
#  'A10MSVOHWFRQQK',
#  'A10MTDYJ4NAF3A',
#  'A10N2PH6L55EMN',
#  'A10NBVRHWXS9BG',
#  'A10NIIWUHCDI0Q',
#  'A10NKN19P7TPWA',
#  'A10NLGRY65BI7W',
#  'A10NMELR4KX0J6',
#  'A10O0BAEKCT7EY',
#  'A10O1CAINE0AMZ',
#  'A10O2JVW1DLSY8',
#  'A10O4LYO967IZ',
#  'A10O78ZQO6POCN',
#  'A10O8SUCJWRCKS',
#  'A10O9K1ZJD27E0',
#  'A10O9OCP1IH953',
#  'A10OB7F3IN0KK7',
#  'A10OBLFPRSTJVY',
#  'A10OE0EV7ZN39E',
#  'A10OFUFIMU1VMZ',
#  'A10OHFUP4O11ZC',
#  'A10OHYECUXI9AC',
#  'A10OSXF1QA4V42',
#  'A10OUJX9WMHINW',
#  'A10OWHY5P8KGWT',
#  'A10OWOLA9LTH00',
#  'A10OZVCL6R94AA',
#  'A10P0QQFNIB1DT',
#  'A10P2NZGZ0J8MD',
#  'A10P6XIDTP419N',
#  'A10PBRJS3D48C6',
#  'A10PD71ALS7L09',
#  'A10PWJ7FERI42Q',
#  'A10Q5N7CMM9U39',
#  'A10Q7DQB33A588',
#  'A10Q85BM42A2FH',
#  'A10Q8GGHPH3CA6',
#  'A10Q8J7R8LHD23',
#  'A10Q9HWRNIV1UF',
#  'A10Q9YNZKI0KPQ',
#  'A10QACG2EFNMY3',
#  'A10QC9P9UKGIYS',
#  'A10QCZG24QTSEJ',
#  'A10QDNXUAJ80T8',
#  'A10QJ2MVWLZ5J3',
#  'A10QRHT3U49611',
#  'A10QTIPE8JGMT3',
#  'A10QWUWW7ANVS',
#  'A10QZYTVJG6WC',
#  'A10R0P62EQT1S5',
#  'A10R0YV68WHVTU',
#  'A10R4QCACWDNES',
#  'A10R7SV028XDWI',
#  'A10R9LB4QJNG5X',
#  'A10RASERL6Y6BP',
#  'A10RD34ZMOB3TC',
#  'A10RMNKMYEAQJ4',
#  'A10RUVQVMTVS56',
#  'A10RVS5MQ1ABIG',
#  'A10S0E5K2EK916',
#  'A10SCCI6XBCDVX',
#  'A10SJ3KIHW8EBZ',
#  'A10STOXA5334FW',
#  'A10SWOV1EF9WU5',
#  'A10SX71DXJPJ72',
#  'A10SXEY0KLC42P',
#  'A10SXU9REBKLRA',
#  'A10SY55NCZB3XA',
#  'A10SZUKETJD6VH',
#  'A10T13K1ZNSR1I',
#  'A10T42SVR3BGYP',
#  'A10TEPJ2NCS38H',
#  'A10TGMHJU2I8HS',
#  'A10TGWRNXV1M6C',
#  'A10THR1YV3XFH1',
#  'A10TIWCAJI4RXS',
#  'A10TMKVI6V009Y',
#  'A10TNHYY7O4UFF',
#  'A10TOOAKPYW81D',
#  'A10TQODHSDP3UK',
#  'A10TYGME2FQHO7',
#  'A10U1BIYS07YGQ',
#  'A10U4D5LGW7D8O',
#  'A10U4OEEU3C9WI',
#  'A10U593OV6ZOCV',
#  'A10U5L2OQV2MJT',
#  'A10UA7QL08U0BJ',
#  'A10UC0B3XLJLO1',
#  'A10UCZ5PWKFHON',
#  'A10UFDBFY89V1C',
#  'A10UHQ7SM1BWFI',
#  'A10UHQH1YL5Q6B',
#  'A10UIYR4Y9F849',
#  'A10UM386E8GNKB',
#  'A10UN2QNBOSQ7Y',
#  'A10UP0JUU4M0QX',
#  'A10V0I4047U8FN',
#  'A10V3AEA4MZ97J',
#  'A10V4HD4541ZWY',
#  'A10V7IN13784TK',
#  'A10V9KWHXEBBCK',
#  'A10VAJV95G5L37',
#  'A10VBC5PBRBH3E',
#  'A10VDLEO35I25F',
#  'A10VYNMVS32Z2F',
#  'A10W2WHZEH9KY2',
#  'A10W88Y3K9QVMI',
#  'A10WAMBFRBBTRH',
#  'A10WC2DB4GXBYT',
#  'A10WHP2VXX5YIS',
#  'A10WX4UBTW6G0W',
#  'A10X3HFIUGCYPT',
#  'A10X7ODCRLZFY0',
#  'A10XAM1TSY3A2T',
#  'A10XLFE3T83WQM',
#  'A10XLVOHNH8NNS',
#  'A10XPGFCXYVCAC',
#  'A10XPVCHSAZOWX',
#  'A10XQJYDEE4CF4',
#  'A10XQOTVDQMYB1',
#  'A10XU998SZBNJG',
#  'A10XUNPSVVWC7O',
#  'A10XVDFYOVT7ED',
#  'A10Y0CLCJ1L4LA',
#  'A10Y0RNRVP2ZIV',
#  'A10Y59HW4O47N0',
#  'A10Y5CETVZ89WI',
#  'A10Y6DKBE3MFOA',
#  'A10Y7IGX6BY5KI',
#  'A10Y90SNL35EZ0',
#  'A10Y96F4H9N2PB',
#  'A10YG7VZ8DI63X',
#  'A10YMDRAAMISIF',
#  'A10YNGCGT5I6WT',
#  'A10YO15QND3PCB',
#  'A10YOXMVHR0KEO',
#  'A10YPHHHEWW6R0',
#  'A10YPWULZPVT10',
#  'A10YSUFFO9MXTJ',
#  'A10YXAS90UCU7E',
#  'A10YXF0BN1LJPF',
#  'A10YZBN2QSBZCU',
#  'A10Z0ANBXZX1T0',
#  'A10Z2KZF69WCKZ',
#  'A10Z2RP8PPREMF',
#  'A10Z3SVN7GM96I',
#  'A10Z8FC0SMU5VQ',
#  'A10ZBR6O8S8OCY',
#  'A10ZJFBZGIHCSR',
#  'A10ZJGMNM6UYIM',
#  'A10ZK1IH0PDGJU',
#  'A10ZLJBEEEGLWG',
#  'A10ZM1D568O4JP',
#  'A10ZMH4RZNKBX',
#  'A10ZSJA04HF6CX',
#  'A10ZUHBLFP8ONG',
#  'A10ZVQANYOONAU',
#  'A10ZW9UDS0THWB',
#  'A10ZZ8Q4OU3NVK',
#  'A1101O39CXUFL',
#  'A1107WDLC8DROO',
#  'A1108V3NFRZHQK',
#  'A110AFBE979HFW',
#  'A110EPSMWIKE1T',
#  'A110EZJQDQ0RXG',
#  'A110GSSPW2XWZJ',
#  'A110IIBZMZG6R1',
#  'A110IXBU6GAMID',
#  'A110J7F0BBC3E7',
#  'A110LZFBUFYWN7',
#  'A110MFNLUJVVYW',
#  'A110Q7P00C6WM7',
#  'A110QUC2ULFN7R',
#  'A110SBER4TRW2O',
#  'A110SXU1PB474S',
#  'A110UY5OJ7AYHO',
#  'A1111BN0NVU685',
#  'A1115QTK50JCI7',
#  'A1116GG1MBIU71',
#  'A1119HMZP17P2C',
#  'A111BKOEHIQYGX',
#  'A111BT9VSZ2A5C',
#  'A111DK44LA8VT5',
#  'A111EC1NAD5LVH',
#  'A111JBAN13SBLN',
#  'A111TAZAO1RCPV',
#  'A111TNGITR8X3Z',
#  'A111U0FJ58SJDB',
#  'A111XJY4XSDIY9',
#  'A111Y9QLUBHKNW',
#  'A111ZAXHIADWI',
#  'A111ZBSJDBZR33',
#  'A111ZMX6D5M7BU',
#  'A1120E5SBOKJ63',
#  'A1123GA5M6UDTU',
#  'A1124PSXYS9XFX',
#  'A1128KVAN0KAQ8',
#  'A112APD2POLSKR',
#  'A112I1SRHP5T0K',
#  'A112I6EQNGXI38',
#  'A112PN9LDIQZQX',
#  'A112PNKAKQ4ABN',
#  'A1131JF0YNOW3G',
#  'A1136FW4JYZ8PS',
#  'A1139B9Z9WX06G',
#  'A113CLSTHREXUB',
#  'A113IIYOI3K46Y',
#  'A113IZ4NB6JJSA',
#  'A113U8PF9I64BN',
#  'A11478K7Y4MEWN',
#  'A1148WBIBTMXQJ',
#  'A1148XB5BB9FRB',
#  'A114BJSY2N0AUX',
#  'A114MH965YFHAX',
#  'A114NKQU04G0XX',
#  'A114WC65K1IL31',
#  'A1152KOCHZ20Q7',
#  'A1157CR0T5UM9D',
#  'A115BQ2D8NI0MX',
#  'A115BQ6PANY6ZG',
#  'A115CZFOBU5PQL',
#  'A115DN1L5IUNTR',
#  'A115EDVRH38DBB',
#  'A115FKKTVGG3X8',
#  'A115GQ3JX5Q84L',
#  'A115HRES7RTR5B',
#  'A115K2JUGJBHUQ',
#  'A115P1QHLDDWYZ',
#  'A115QAIJJPTUBW',
#  'A115Z929RXDBY7',
#  'A1160IB5N03NOV',
#  'A1167H3P5WJPU9',
#  'A116CKL27LPX38',
#  'A116FKNXNLLMTI',
#  'A116HPH8UDEAOX',
#  'A116HT1CCZ60ON',
#  'A116J7RKTBS314',
#  'A116K99MQP5RUK',
#  'A116VMZPUYEW8Y',
#  'A1175EAKD9S6JU',
#  'A1176BXBM7IWEZ',
#  'A11787KLJQOXTK',
#  'A117B3QAGUDV1O',
#  'A117BJSC3PPTB3',
#  'A117FR976LYO04',
#  'A117IKHHAVS0MQ',
#  'A117K1W206D8CN',
#  'A117O9N8VHFGC9',
#  'A117ST5ZLY9YNK',
#  'A117TCJ30OUVLK',
#  'A117XUS2KI1M04',
#  'A118EBQR92RP1T',
#  'A118HRSV9MQYHH',
#  'A118P0ZV6LAF3Q',
#  'A118QOZ6Q6515S',
#  'A118T2O9BIVCAX',
#  'A118TYPUXA4V2R',
#  'A118UQILJZOYEY',
#  'A118Z7JQ89WII1',
#  'A1190B7GAN6CEW',
#  'A119261VGRTCF8',
#  'A1192KPCYERLNE',
#  'A1194J7P3U2AO9',
#  'A119B3DAVTMYBZ',
#  'A119DZC9OOXNHS',
#  'A119JDKIZMQXB3',
#  'A119RW19UWK7PH',
#  'A119T8GFAA0NU7',
#  'A11A6KBAHU9GKO',
#  'A11A9AVEM5EVU4',
#  'A11A9PHLBSP29D',
#  'A11AAABJ1DUT6A',
#  'A11ACQW8RYEVMF',
#  'A11AGS05TCAQWL',
#  'A11AKBPI90F374',
#  'A11ANQPM48JG3C',
#  'A11APOC3HC8GSP',
#  'A11AREVH08R8K4',
#  'A11ARPRHGF1HEP',
#  'A11AT2JLH0113E',
#  'A11B06ECPLR2EP',
#  'A11B2DJ9P4KNET',
#  'A11B9Q2K0OUF39',
#  'A11BC45G7HQ5XN',
#  'A11BFJQ7VWPRCR',
#  'A11BHO3U7NACGO',
#  'A11BKFD2XDF3MZ',
#  'A11BM9BFN81RPE',
#  'A11BNA8NALLF0I',
#  'A11BNX7GXLGOVD',
#  'A11BPP25Z179ZC',
#  'A11BURN21BSG1U',
#  'A11BXH2FE9LPUU',
#  'A11C1IHP88PWH5',
#  'A11C1V2AE5LRLA',
#  'A11C20CTKTVNK2',
#  'A11C5TQL2U9CBL',
#  'A11C7V9YHXXXBN',
#  'A11CGWWRSH93WK',
#  'A11CH52DG6EF6P',
#  'A11CHG53SRXLUX',
#  'A11CIYJ0X7TXCZ',
#  'A11CMADEULA2M1',
#  'A11CNHG8DPLGN8',
#  'A11COG36AY808I',
#  'A11CP8HO8QLF5J',
#  'A11CTBMQSHS66G',
#  'A11CWV66S1OASJ',
#  'A11CXFCLSR5AFL',
#  'A11D1A3X7FMCWE',
#  'A11D1KHM7DVOQK',
#  'A11D1O6A9S6J7R',
#  'A11D7VUDD2IULE',
#  'A11D87RQW3ERDT',
#  'A11D8B0C07ZMQ2',
#  'A11DE6PAZ8D2WW',
#  'A11DKU28PBEM0K',
#  'A11DMF3B8389XC',
#  'A11DNPXY3QUONM',
#  'A11DSDW9C2QQNE',
#  'A11DUBJGHUPSMD',
#  'A11DW4QC5UVHTA',
#  'A11E45I3RGY3I5',
#  'A11E8RKIE9NIC9',
#  'A11E97POD1SB80',
#  'A11ED8O95W2103',
#  'A11EEQCKYF9M0M',
#  'A11EIDY6DD40CS',
#  'A11EKWY0WDPQKL',
#  'A11ESJ4EBRZ3QJ',
#  'A11ET0ZSSC8V3H',
#  'A11EWQ8LJZ38GT',
#  'A11EXABIXSKUFD',
#  'A11EYMH9UV9XG7',
#  'A11F87LHCF6KV2',
#  'A11F9JX4Q84U8H',
#  'A11FKO9FLDOCTG',
#  'A11FNE7L67N6QS',
#  'A11FVLVZHPJM2D',
#  'A11G9P0EE7KIBP',
#  'A11GAF8ZEHZPJX',
#  'A11GAMN6HED4U1',
#  'A11GDNNAG67HU2',
#  'A11GY4A7Y4HYNP',
#  'A11GZVTJHVX1KY',
#  'A11H3JB3UWKTXZ',
#  'A11HCEFDQ7T0K2',
#  'A11HIJSIM4NCZV',
#  'A11HIUFTTYEGIA',
#  'A11HKNH1RSBC4B',
#  'A11HKPOWWYDYMB',
#  'A11HMD9I0A0L3P',
#  'A11HYL4V9G2X7F',
#  'A11I1I9QLMAM1A',
#  'A11I8LB7MCNRGJ',
#  'A11ID30CX0WGMF',
#  'A11IIPW01CSL0D',
#  'A11IJMMES6CQXK',
#  'A11IJZT5L82ONF',
#  'A11IM2S214PAVR',
#  'A11IS0BB07AGDY',
#  'A11IWKE314RIQ5',
#  'A11IZD0G0AB27R',
#  'A11J0WMGXTB98Y',
#  'A11J39GMXVI0FT',
#  'A11J7EOZFK4VX0',
#  'A11J8NSSZRRIQ1',
#  'A11JBX076BF8AQ',
#  'A11JCNY9D1R145',
#  'A11JDIFMAAVHC3',
#  'A11JN9KSF5OJ05',
#  'A11JQWH93M2T4E',
#  'A11JS5RTL6YD76',
#  'A11JTEHRSACSKD',
#  'A11JTHEOGP5XA7',
#  'A11JUOCIOK1I7',
#  'A11JWEBDNZO542',
#  'A11JX6MA3TEQK',
#  'A11JXS9PB728PD',
#  'A11K6RJ843JQG6',
#  'A11K70GWSB7A5Z',
#  'A11K83SZ0W14CE',
#  'A11K891VP1HXFH',
#  'A11KC08K9F2F4B',
#  'A11KE9BRGPOXLY',
#  'A11KEDJL2XIOAR',
#  'A11KJMDLLLGW3H',
#  'A11KQYYJF9UATR',
#  'A11KT99IG46MQU',
#  'A11KUPKDI7MJTJ',
#  'A11KXW5JQBG1OT',
#  'A11L29WJU8L2GR',
#  'A11L4SBY7NCSZU',
#  'A11L52K6VOL7D2',
#  'A11L6D2KZH3SDK',
#  'A11L90R7RWJA8H',
#  'A11LDBLT78KRZF',
#  'A11LEIEL8JQWH8',
#  'A11LK9F8VK9C0E',
#  'A11LNPG39A2ZV4',
#  'A11LNY2OLQSUSV',
#  'A11LSFB4HHH45I',
#  'A11LUFMAEAZ6LP',
#  'A11MBYYDBV3M48',
#  'A11MCNZSTBW4UE',
#  'A11MJWNRVQG65X',
#  'A11MOMHYE9C7KF',
#  'A11MOQ9B4J0GJL',
#  'A11MRQZTDV0LOE',
#  'A11MZ68XJJUDUC',
#  'A11N6Y2ELG1JJN',
#  'A11NFERETUWA8Z',
#  'A11NFVEZ2VOM72',
#  'A11NKNRFYVGNTD',
#  'A11NOO384U6BTX',
#  'A11NOXIBYIZKDM',
#  'A11NRJ4OO6DKS3',
#  'A11NU1JOUG4KBX',
#  'A11NVPIQXPS15P',
#  'A11NYFA81STVQC',
#  'A11NYNRGY1RXQJ',
#  'A11O2CFMG92HGS',
#  'A11O3OMAMCUD7G',
#  'A11O80MBZGIS9V',
#  'A11OAK8NM6O8VO',
#  'A11OO1TV061PYA',
#  'A11OO6XEBYT8CS',
#  'A11OTLEDSW8ZXD',
#  'A11OUNFH7EHW3I',
#  'A11P0HJAFVRKW1',
#  'A11P335DE3Y7F6',
#  'A11P5OZXKXPROT',
#  'A11PKTC7A95ST',
#  'A11PKVBGCKRVEK',
#  'A11PKZN95I6IVD',
#  'A11POLRQK6W5GU',
#  'A11PRA5SXVFU9O',
#  'A11PTCZ2FM2547',
#  'A11PTL0K8IA56Z',
#  'A11PTYEGO90ZIF',
#  'A11PZ6HSK13L66',
#  'A11PZGYVN49F28',
#  'A11Q7CZJ2RBLH0',
#  'A11Q90ZYMIGL25',
#  'A11QD9H9KTEK45',
#  'A11QE0UV68L3KJ',
#  'A11QF0JR3IFSDL',
#  'A11QF9LG7EY705',
#  'A11QKD8EOBIT7G',
#  'A11QTPSDKVH7HV',
#  'A11QU2TY18JGFS',
#  'A11QWUA100WXP1',
#  'A11R14LKY9ULXX',
#  'A11R512CNCXBVQ',
#  'A11RDR6D4NN0TY',
#  'A11RL6V1LENI44',
#  'A11RNMZNAO08F4',
#  'A11RO54KL67B3C',
#  'A11RTJ8V435GGA',
#  'A11RXLUXGXNZHC',
#  'A11S1MOMCLCDXM',
#  'A11S2A6RH32YU2',
#  'A11SCZR1NRBWMJ',
#  'A11SDECT20DPAB',
#  'A11SKZMBUBWY4',
#  'A11SL48M5DER6J',
#  'A11SN2L1LAT2WH',
#  'A11SOYEI98SG84',
#  'A11SPSEM08VIXX',
#  'A11STAIF0BFAXG',
#  'A11SW3BPSQ5Y29',
#  'A11SWG9T60IQH8',
#  'A11SWZ478VKELZ',
#  'A11SXJ2H7IC8J7',
#  'A11SYXOB1SYI58',
#  'A11T4VHNHOA8RF',
#  'A11TAE9HDSQSH5',
#  'A11TNOA283YO1T',
#  'A11TT6FAUKM6N3',
#  'A11TVTMF4XINOM',
#  'A11TZ2AGK9B0V5',
#  'A11U3CLMC40VVG',
#  'A11U4N15LLA2KN',
#  'A11U53F2TH9Y9H',
#  'A11U55QMR4S3DN',
#  'A11U57F6TBTH0F',
#  'A11U6DQP3AP2JJ',
#  'A11UD5TNNXRCC',
#  'A11UHSGMRVKB8I',
#  'A11UJ1T05EN11W',
#  'A11UKHHU3G78QU',
#  'A11UMAQLP6CQ3E',
#  'A11UNJ6AMPS3NT',
#  'A11UOS00RPZ3SA',
#  'A11UPNFYDICF3C',
#  'A11UPZ6LI1UJZY',
#  'A11USIIZMKH45X',
#  'A11UU9EQQ6EOVZ',
#  'A11UUTKIBOEJRW',
#  'A11UYRORMXDK1F',
#  'A11V8XN8SUHPOV',
#  'A11VA091T7P5B3',
#  'A11VCA9C566BTZ',
#  'A11VEP7ZMZ53WN',
#  'A11VGQM5S7RMEL',
#  'A11VMLDDMER8H7',
#  'A11VST14V6K4S6',
#  'A11W12861H73AB',
#  'A11W2UDL83266A',
#  'A11WAEQIABD2FR',
#  'A11WBEK5XODYVM',
#  'A11WCA0E8DSXL0',
#  'A11WJ6C9N3CIDU',
#  'A11WJYL9J9JX4N',
#  'A11WMI3061LJ6V',
#  'A11WNUTGYLP9HN',
#  'A11WPBIJOKBHL',
#  'A11WS2EP796UNP',
#  'A11WYHDB1YEZOX',
#  'A11X4R2NUJAE94',
#  'A11X6WC59UDF4Y',
#  'A11XAIFA10G7TS',
#  'A11XCC3TATLX26',
#  'A11XCJZ6I4KWG6',
#  'A11XGM9XILGPCQ',
#  'A11XH5DNYP2LGE',
#  'A11XK2HTZN96BQ',
#  'A11XKS3TA7XZ3K',
#  'A11XO7FQ90C8Y4',
#  'A11XPYF0IF2XQE',
#  'A11Y0IAP9EPA62',
#  'A11Y291KSIU9F1',
#  'A11Y8R5SI2VG1T',
#  'A11Y8VRBPF8Z0K',
#  'A11YF0B36S70HY',
#  'A11YFSH8PQXHA6',
#  'A11YKHECDV0ZTC',
#  'A11YOFLF71GKE9',
#  'A11YOTONCPRQ9S',
#  'A11YSRIHU2QS1Z',
#  'A11YTJOTZ8WLX9',
#  'A11YZSEN83VHQ3',
#  'A11Z127DUM7RN2',
#  'A11Z46SBOWP6Z',
#  'A11Z4Y95AIJHYA',
#  'A11Z7GIR2ZCEBD',
#  'A11Z81ADK6TUSY',
#  'A11Z8F0841ES2F',
#  'A11ZAHAIYB2455',
#  'A11ZDK05HW9CCQ',
#  'A11ZIT3YGDOX00',
#  'A11ZOEJY15NTMW',
#  'A11ZON1YDEVYGC',
#  'A11ZSVQGNB0LGF',
#  'A11ZTWJ9LC8QQY',
#  'A1200DHK397LJS',
#  'A12038VS9VKA9L',
#  'A1205T8NP2BQ5E',
#  'A120EP5BKAUB5N',
#  'A120OYPSBNU0GI',
#  'A120P0MIV4OALC',
#  'A120PZKEGSIFUV',
#  'A120RS2138W2WT',
#  'A120URHCXRDAPQ',
#  'A1214B8C047KQ9',
#  'A1215H6VOUCP5V',
#  'A121629E4DPO6J',
#  'A1217IET6K218P',
#  'A121C3RIG79BGK',
#  'A121DPPBR03OFZ',
#  'A121FWNEJV0KG2',
#  'A121I1LNFX3AP2',
#  'A121IBNP53HIAD',
#  'A121PLHXGZXXUJ',
#  'A121Q0I5X2BV4T',
#  'A121YIMUUBE7E3',
#  'A1220N61SCVS4Z',
#  'A122BBYG5UH28E',
#  'A122I5424CXUEJ',
#  'A122ME3ZYQCTAY',
#  'A122QWG326YS1O',
#  'A122RTKEMU1I8V',
#  'A1232A261G238Y',
#  'A1233Q0JC6BB38',
#  'A123467FCJCBYU',
#  'A1235J5HSC60MW',
#  'A1235MZRMVOL4D',
#  'A123879TGBH5LB',
#  'A1239CM70LZ9HK',
#  'A123BF0IV40AN1',
#  'A123EOLU79BS8K',
#  'A123HHC0ZA3Z2Y',
#  'A123I1OGU0W0NG',
#  'A123JVOPVZIBI6',
#  'A123JYX59BJ1RE',
#  'A123QAQ3JXF72V',
#  'A123RSRNMFPOYO',
#  'A123WPCHJ09USJ',
#  'A123WYKQZJ9ABH',
#  'A1249YEXRTFIV2',
#  'A124F28PRZ85W7',
#  'A124GQ4H5EMP9I',
#  'A124J67X2DW82M',
#  'A124PSAV4UV3BX',
#  'A124QQFDG53C1P',
#  'A124RKNHGHLULG',
#  'A124S1NSY03CR9',
#  'A124THO7AI00QR',
#  'A124U1TNAOHZP6',
#  'A124URARVE9S89',
#  'A124VGEBZLR6E7',
#  'A124XHWH94NKUN',
#  'A1254JT4BZ4IWS',
#  'A12579OACG87H6',
#  'A12596IFBLEZRJ',
#  'A125BP8ALTVU1G',
#  'A125D7HOC89K1I',
#  'A125DAWEYGUMXQ',
#  'A125EN0MBAB3CP',
#  'A125I4JZKQUXGQ',
#  'A125PN0NWGQFM1',
#  'A125PRRZRCE2IS',
#  'A125X4KG66VJ3K',
#  'A125Y24R91RCKU',
#  'A1260GRZDL3KKT',
#  'A1264ZVF2WFGKT',
#  'A12652OXJRECI0',
#  'A126GLPNRADEQL',
#  'A126HHM41FEIZA',
#  'A126HUYRT15U5Y',
#  'A126IC6EKVTJCB',
#  'A126KX6FVI4T66',
#  'A126O8KD5XZTLR',
#  'A126Q2HVTCS9P2',
#  'A126U6T5VTFV2W',
#  'A126XL4FMPWBH5',
#  'A1273EI16LRMTP',
#  'A127624DPDNUF0',
#  'A12780DLAT4VWP',
#  'A127D9M5LL6RBB',
#  'A127F1XMB78ERP',
#  'A127KQKFWI4P4N',
#  'A127N629MFMXKN',
#  'A127X8E4W2UMBG',
#  'A128572ZQTGBU',
#  'A1285HWVYDHTBX',
#  'A12899XA4V1RIY',
#  'A128DSVNBMTYTY',
#  'A128T00RX0JOS2',
#  'A128UL0AO1ZPOS',
#  'A128XW375N43N4',
#  'A128Z73554FM1I',
#  'A1295JW2NJGCVK',
#  'A129ACOZ9ZLQNV',
#  'A129EBKNH5BKZI',
#  'A129EYB4DS7Q5P',
#  'A129FMUHM7NYGY',
#  'A129FZ5BFFUK87',
#  'A129K7NK4CR5GC',
#  'A129SP8NCH0XL1',
#  'A129WRS2XC0UO4',
#  'A129Z0VZ7VPXT0',
#  'A12A2VHTVG5AB',
#  'A12A7189ZWX24B',
#  'A12ACM2AJZ4ONI',
#  'A12ACMPEF56QX4',
#  'A12AEGP7LW3DLS',
#  'A12AEP2O0PC0ID',
#  'A12AFHC6S9FA5',
#  'A12AGNSRFTD2J3',
#  'A12AIV3KNF2720',
#  'A12ALEBGET1UZ0',
#  'A12AQ25KN40SNR',
#  'A12ARB067ONGT5',
#  'A12AT0RMHHE2BS',
#  'A12B0ARL5HRGQA',
#  'A12B30R79VEMTR',
#  'A12BAN54QIOI0L',
#  'A12BKTJSJVVQTU',
#  'A12BSNZNKBQ3WQ',
#  'A12BTR2MVK2BR5',
#  'A12BVUR4J6C78N',
#  'A12BWPJGMPOO3Y',
#  'A12BWQ140VJ40Z',
#  'A12BX7LUVB86Q4',
#  'A12C38M5DOIPD',
#  'A12C3UTX5JGAMU',
#  'A12C6PDUBQDTL7',
#  'A12C6UTM4DRCW4',
#  'A12CBDHX1MJLGZ',
#  'A12CERA1VD8Z3V',
#  'A12CM28ILOSZ3Y',
#  'A12CNJOKLRHUWE',
#  'A12CPPY9OIRRK2',
#  'A12CTZEFRE9K2H',
#  'A12D1F0XB6E4PO',
#  'A12D1KTEGHPDO2',
#  'A12D639RF1F0IG',
#  'A12DJHDKTOA69W',
#  'A12DJTFPXQ70CH',
#  'A12DMM4LL66N4W',
#  'A12DNMKPJASFJ0',
#  'A12DPTSN2GB6Z8',
#  'A12E0TM5FA30W4',
#  'A12E13PYXQN795',
#  'A12E1Z3XQ0ZVLP',
#  'A12E2KPAXV0ZMK',
#  'A12E3M3DN8CW12',
#  'A12E48Q7T9D3KT',
#  'A12E7HIEPFIFHW',
#  'A12E942R4PXLJ9',
#  'A12EDGP5ZGZVJD',
#  'A12EDL87FL2PII',
#  'A12EF0UWQ0FP2I',
#  'A12ENBT314RFXR',
#  'A12ENZOVKKR5IL',
#  'A12EQSUZ8NOFMZ',
#  'A12ET4S0G6EQGN',
#  'A12EV3UA4JCDLF',
#  'A12EXOVDVBRYT1',
#  'A12EYBZ7QO3NK8',
#  'A12EZUL89ERV86',
#  'A12F3TS5S4RA74',
#  'A12F886O36KSF1',
#  'A12FCM3B3UK96O',
#  ...]

# %%
#while using all the data took too much time to compile, I worked with sampled data
subset = df.sample(frac=0.1)

pivot_table = subset.pivot_table(index='userId', columns='product_id', values='score')
pivot_table
# Out:
# product_id          7310172001  7310172101  B00005IX96  B00005IX98  \
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# product_id          B00006IDJO  B00006IDJU  B00008434E  B000084388  \
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# product_id          B000084DWM  B000084E9J  ...  B009I31XNI  B009JYEBS0  \
# userId                                      ...
# #oc-R3LI5WJM4WD02C         NaN         NaN  ...         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN  ...         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN  ...         NaN         NaN
# A102714YQ4VYZP             NaN         NaN  ...         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN  ...         NaN         NaN
# ...                        ...         ...  ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN  ...         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN  ...         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN  ...         NaN         NaN
# AZYU563S6AOK9              NaN         NaN  ...         NaN         NaN
# AZZNK89PXD006              NaN         NaN  ...         NaN         NaN
#
# product_id          B009LIK0FW  B009MRNOR8  B009NTCO4O  B009O0U2SW  \
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# product_id          B009O7DGEW  B009OM66IU  B009PCDDO4  B009QEBGIQ
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# [6944 rows x 7426 columns]

# %%
def normalize_rows(row):
    row_sum = int(row.sum())
    return row.div(row_sum)

result = pivot_table.apply(normalize_rows, axis=1)
#a memory problem occurs here
result
# Out:
# product_id          7310172001  7310172101  B00005IX96  B00005IX98  \
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# product_id          B00006IDJO  B00006IDJU  B00008434E  B000084388  \
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# product_id          B000084DWM  B000084E9J  ...  B009I31XNI  B009JYEBS0  \
# userId                                      ...
# #oc-R3LI5WJM4WD02C         NaN         NaN  ...         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN  ...         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN  ...         NaN         NaN
# A102714YQ4VYZP             NaN         NaN  ...         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN  ...         NaN         NaN
# ...                        ...         ...  ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN  ...         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN  ...         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN  ...         NaN         NaN
# AZYU563S6AOK9              NaN         NaN  ...         NaN         NaN
# AZZNK89PXD006              NaN         NaN  ...         NaN         NaN
#
# product_id          B009LIK0FW  B009MRNOR8  B009NTCO4O  B009O0U2SW  \
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# product_id          B009O7DGEW  B009OM66IU  B009PCDDO4  B009QEBGIQ
# userId
# #oc-R3LI5WJM4WD02C         NaN         NaN         NaN         NaN
# #oc-R40PWE1BFHMT2          NaN         NaN         NaN         NaN
# #oc-RNMDR27B0MP1I          NaN         NaN         NaN         NaN
# A102714YQ4VYZP             NaN         NaN         NaN         NaN
# A102NQYJ3LLR7V             NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# AZWF1BM21B1OK              NaN         NaN         NaN         NaN
# AZX18A7F4ZBXB              NaN         NaN         NaN         NaN
# AZYTCGDO3R4ZU              NaN         NaN         NaN         NaN
# AZYU563S6AOK9              NaN         NaN         NaN         NaN
# AZZNK89PXD006              NaN         NaN         NaN         NaN
#
# [6944 rows x 7426 columns]

# %%
result_T = result.T
user_similarity = result.dot(result_T)
product_similarity = result_T.dot(result)

user_similarity
# Out:
# userId              #oc-R3LI5WJM4WD02C  #oc-R40PWE1BFHMT2  #oc-RNMDR27B0MP1I  \
# userId
# #oc-R3LI5WJM4WD02C                 NaN                NaN                NaN
# #oc-R40PWE1BFHMT2                  NaN                NaN                NaN
# #oc-RNMDR27B0MP1I                  NaN                NaN                NaN
# A102714YQ4VYZP                     NaN                NaN                NaN
# A102NQYJ3LLR7V                     NaN                NaN                NaN
# ...                                ...                ...                ...
# AZWF1BM21B1OK                      NaN                NaN                NaN
# AZX18A7F4ZBXB                      NaN                NaN                NaN
# AZYTCGDO3R4ZU                      NaN                NaN                NaN
# AZYU563S6AOK9                      NaN                NaN                NaN
# AZZNK89PXD006                      NaN                NaN                NaN
#
# userId              A102714YQ4VYZP  A102NQYJ3LLR7V  A10389W8OI4Q6N  \
# userId
# #oc-R3LI5WJM4WD02C             NaN             NaN             NaN
# #oc-R40PWE1BFHMT2              NaN             NaN             NaN
# #oc-RNMDR27B0MP1I              NaN             NaN             NaN
# A102714YQ4VYZP                 NaN             NaN             NaN
# A102NQYJ3LLR7V                 NaN             NaN             NaN
# ...                            ...             ...             ...
# AZWF1BM21B1OK                  NaN             NaN             NaN
# AZX18A7F4ZBXB                  NaN             NaN             NaN
# AZYTCGDO3R4ZU                  NaN             NaN             NaN
# AZYU563S6AOK9                  NaN             NaN             NaN
# AZZNK89PXD006                  NaN             NaN             NaN
#
# userId              A103OW9PCYAXXH  A105WK4IF15MXJ  A106MB2IVYFRWR  \
# userId
# #oc-R3LI5WJM4WD02C             NaN             NaN             NaN
# #oc-R40PWE1BFHMT2              NaN             NaN             NaN
# #oc-RNMDR27B0MP1I              NaN             NaN             NaN
# A102714YQ4VYZP                 NaN             NaN             NaN
# A102NQYJ3LLR7V                 NaN             NaN             NaN
# ...                            ...             ...             ...
# AZWF1BM21B1OK                  NaN             NaN             NaN
# AZX18A7F4ZBXB                  NaN             NaN             NaN
# AZYTCGDO3R4ZU                  NaN             NaN             NaN
# AZYU563S6AOK9                  NaN             NaN             NaN
# AZZNK89PXD006                  NaN             NaN             NaN
#
# userId              A106R34K3VRITJ  ...  AZSE0K98A68HT  AZTO5GI7MFUAB  \
# userId                              ...
# #oc-R3LI5WJM4WD02C             NaN  ...            NaN            NaN
# #oc-R40PWE1BFHMT2              NaN  ...            NaN            NaN
# #oc-RNMDR27B0MP1I              NaN  ...            NaN            NaN
# A102714YQ4VYZP                 NaN  ...            NaN            NaN
# A102NQYJ3LLR7V                 NaN  ...            NaN            NaN
# ...                            ...  ...            ...            ...
# AZWF1BM21B1OK                  NaN  ...            NaN            NaN
# AZX18A7F4ZBXB                  NaN  ...            NaN            NaN
# AZYTCGDO3R4ZU                  NaN  ...            NaN            NaN
# AZYU563S6AOK9                  NaN  ...            NaN            NaN
# AZZNK89PXD006                  NaN  ...            NaN            NaN
#
# userId              AZUSUNUP7S8U8  AZV26LP92E6WU  AZVWJW247I1HC  \
# userId
# #oc-R3LI5WJM4WD02C            NaN            NaN            NaN
# #oc-R40PWE1BFHMT2             NaN            NaN            NaN
# #oc-RNMDR27B0MP1I             NaN            NaN            NaN
# A102714YQ4VYZP                NaN            NaN            NaN
# A102NQYJ3LLR7V                NaN            NaN            NaN
# ...                           ...            ...            ...
# AZWF1BM21B1OK                 NaN            NaN            NaN
# AZX18A7F4ZBXB                 NaN            NaN            NaN
# AZYTCGDO3R4ZU                 NaN            NaN            NaN
# AZYU563S6AOK9                 NaN            NaN            NaN
# AZZNK89PXD006                 NaN            NaN            NaN
#
# userId              AZWF1BM21B1OK  AZX18A7F4ZBXB  AZYTCGDO3R4ZU  \
# userId
# #oc-R3LI5WJM4WD02C            NaN            NaN            NaN
# #oc-R40PWE1BFHMT2             NaN            NaN            NaN
# #oc-RNMDR27B0MP1I             NaN            NaN            NaN
# A102714YQ4VYZP                NaN            NaN            NaN
# A102NQYJ3LLR7V                NaN            NaN            NaN
# ...                           ...            ...            ...
# AZWF1BM21B1OK                 NaN            NaN            NaN
# AZX18A7F4ZBXB                 NaN            NaN            NaN
# AZYTCGDO3R4ZU                 NaN            NaN            NaN
# AZYU563S6AOK9                 NaN            NaN            NaN
# AZZNK89PXD006                 NaN            NaN            NaN
#
# userId              AZYU563S6AOK9  AZZNK89PXD006
# userId
# #oc-R3LI5WJM4WD02C            NaN            NaN
# #oc-R40PWE1BFHMT2             NaN            NaN
# #oc-RNMDR27B0MP1I             NaN            NaN
# A102714YQ4VYZP                NaN            NaN
# A102NQYJ3LLR7V                NaN            NaN
# ...                           ...            ...
# AZWF1BM21B1OK                 NaN            NaN
# AZX18A7F4ZBXB                 NaN            NaN
# AZYTCGDO3R4ZU                 NaN            NaN
# AZYU563S6AOK9                 NaN            NaN
# AZZNK89PXD006                 NaN            NaN
#
# [6944 rows x 6944 columns]

# %%
product_similarity
# Out:
# product_id  7310172001  7310172101  B00005IX96  B00005IX98  B00006IDJO  \
# product_id
# 7310172001         NaN         NaN         NaN         NaN         NaN
# 7310172101         NaN         NaN         NaN         NaN         NaN
# B00005IX96         NaN         NaN         NaN         NaN         NaN
# B00005IX98         NaN         NaN         NaN         NaN         NaN
# B00006IDJO         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# B009O0U2SW         NaN         NaN         NaN         NaN         NaN
# B009O7DGEW         NaN         NaN         NaN         NaN         NaN
# B009OM66IU         NaN         NaN         NaN         NaN         NaN
# B009PCDDO4         NaN         NaN         NaN         NaN         NaN
# B009QEBGIQ         NaN         NaN         NaN         NaN         NaN
#
# product_id  B00006IDJU  B00008434E  B000084388  B000084DWM  B000084E9J  ...  \
# product_id                                                              ...
# 7310172001         NaN         NaN         NaN         NaN         NaN  ...
# 7310172101         NaN         NaN         NaN         NaN         NaN  ...
# B00005IX96         NaN         NaN         NaN         NaN         NaN  ...
# B00005IX98         NaN         NaN         NaN         NaN         NaN  ...
# B00006IDJO         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# B009O0U2SW         NaN         NaN         NaN         NaN         NaN  ...
# B009O7DGEW         NaN         NaN         NaN         NaN         NaN  ...
# B009OM66IU         NaN         NaN         NaN         NaN         NaN  ...
# B009PCDDO4         NaN         NaN         NaN         NaN         NaN  ...
# B009QEBGIQ         NaN         NaN         NaN         NaN         NaN  ...
#
# product_id  B009I31XNI  B009JYEBS0  B009LIK0FW  B009MRNOR8  B009NTCO4O  \
# product_id
# 7310172001         NaN         NaN         NaN         NaN         NaN
# 7310172101         NaN         NaN         NaN         NaN         NaN
# B00005IX96         NaN         NaN         NaN         NaN         NaN
# B00005IX98         NaN         NaN         NaN         NaN         NaN
# B00006IDJO         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# B009O0U2SW         NaN         NaN         NaN         NaN         NaN
# B009O7DGEW         NaN         NaN         NaN         NaN         NaN
# B009OM66IU         NaN         NaN         NaN         NaN         NaN
# B009PCDDO4         NaN         NaN         NaN         NaN         NaN
# B009QEBGIQ         NaN         NaN         NaN         NaN         NaN
#
# product_id  B009O0U2SW  B009O7DGEW  B009OM66IU  B009PCDDO4  B009QEBGIQ
# product_id
# 7310172001         NaN         NaN         NaN         NaN         NaN
# 7310172101         NaN         NaN         NaN         NaN         NaN
# B00005IX96         NaN         NaN         NaN         NaN         NaN
# B00005IX98         NaN         NaN         NaN         NaN         NaN
# B00006IDJO         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# B009O0U2SW         NaN         NaN         NaN         NaN         NaN
# B009O7DGEW         NaN         NaN         NaN         NaN         NaN
# B009OM66IU         NaN         NaN         NaN         NaN         NaN
# B009PCDDO4         NaN         NaN         NaN         NaN         NaN
# B009QEBGIQ         NaN         NaN         NaN         NaN         NaN
#
# [7426 rows x 7426 columns]

# %%
G_users = nx.from_pandas_adjacency(user_similarity)
G_products = nx.from_pandas_adjacency(product_similarity)

nx.draw(G_users)
nx.draw(G_products)

# %%
#skectching network took too much time to compile. Even after more than a hour, still trying to compile it. 
#I couldn't fix the NaN problem. I tried many methods but none of them worked.
